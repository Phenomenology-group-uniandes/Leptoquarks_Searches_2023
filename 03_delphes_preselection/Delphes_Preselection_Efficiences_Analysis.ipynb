# %% [markdown]
# $$\textrm{Joaquin Peñuela Parra, Cristian Fernando Rodriguez Cruz}$$
# $$\textrm{University of Los Andes}$$
# $$\textrm{High Energy Physics Group: Phenomenology of Particles}$$
#
# This code was written to be running in Docker. If you do not have a Docker inside hep-server2 please refer to: https://github.com/Phenomenology-group-uniandes/Tutoriales_Generales

# %%
#!rm -rf Uniandes_Framework
#!git clone https://github.com/Phenomenology-group-uniandes/Uniandes_Framework.git

# %%
import os, sys
path_f=os.path.join(os.getcwd().split("Leptoquarks_Searches_2023")[0])
sys.path.append(path_f)

from Uniandes_Framework.delphes_reader import DelphesLoader 
from Uniandes_Framework.delphes_reader import clasificator 
from Uniandes_Framework.delphes_reader import root_analysis 
from Uniandes_Framework.delphes_reader import Quiet 

from ROOT import TChain
from ROOT import TLorentzVector

import pandas as pd
from multiprocessing import Pool
# Out:
# Welcome to JupyROOT 6.22/06

# %%
def event_selection(signal):
    
    csv_folder_path = f'/disco4/pheno_csv_files/Leptoquarks_Searches/{signal}/'
    # !mkdir -p {csv_folder_path}    
    
    with Quiet():
    
        CUTS={"l_jet":     {"pt_min_cut":30., "eta_min_cut":-5.,  "eta_max_cut":+5. },
              "b_jet":     {"pt_min_cut":30., "eta_min_cut":-2.4, "eta_max_cut":+2.4},
              "tau_jet":   {"pt_min_cut":50., "eta_min_cut":-2.3, "eta_max_cut":+2.3},
              "other_jet": {"pt_min_cut":0.,  "eta_min_cut":-5.,  "eta_max_cut":+5.},
              "electron":  {"pt_min_cut":35.,  "eta_min_cut":-2.4, "eta_max_cut":+2.4},
              "muon":      {"pt_min_cut":30.,  "eta_min_cut":-2.4, "eta_max_cut":+2.4}}

        ST = []
        
        Delphes = DelphesLoader(signal,os.path.join(path_f,"Uniandes_Framework","SimulationsPaths.csv"))
        Paths = Delphes.Forest
        xs = Delphes.xs   
        
        #We want a Cutflows file for each cathegory:        
        Cutflows = {'hadronic_non-resonant': {'XS': xs},
                    'hadronic_sLQ': {'XS': xs},
                    'hadronic_dLQ': {'XS': xs},
                    'semileptonic_non-resonant': {'XS': xs},
                    'semileptonic_sLQ': {'XS': xs},
                    'semileptonic_dLQ': {'XS': xs}}
        
        kinematic_variables = {}
        for key in Cutflows.keys(): kinematic_variables[key] = []
        i = 0
        for path in Paths:
            if (i == 2): break
            else: i = i + 1
            
            tree = TChain("Delphes;1") 
            tree.Add(path) 
                        
            for event in tree:
                
                for key in Cutflows.keys(): Cutflows[key]['All'] = Cutflows[key].get('All',0) + 1
                    
                leptons = clasificator.get_good_leptons(event, kin_cuts= CUTS) 
                
                if(len(leptons) > 1): continue
                for key in Cutflows.keys(): Cutflows[key]['Maximum 1 light lepton'] = Cutflows[key].get('Maximum 1 light lepton',0) + 1
                           
                jets = clasificator.get_good_jets(event, kin_cuts= CUTS)
                
                #Adding tau_jets like leptons:
                leptons = leptons + jets['tau_jet'] 
                
                if(len(leptons) >= 2):  
                    for key in Cutflows.keys(): Cutflows[key]['At least 2 leptons'] = Cutflows[key].get('At least 2 leptons',0) + 1
                
                if(len(leptons) != 2): continue 
                for key in Cutflows.keys(): Cutflows[key]['Exactly 2 leptons'] = Cutflows[key].get('Exactly 2 leptons',0) + 1

                #At this point, we have two hadronic taus or one hadronic tau and one lepton. Now, we can clasificate:
                
                #clasification:
                if(len(jets['tau_jet']) == 1): 
                    label1 = 'semileptonic'
                else:
                    label1 = 'hadronic'  
                
                    
                cut = f'{label1} selection'    
                for key in Cutflows.keys(): 
                    if label1 in key: Cutflows[key][cut] = Cutflows[key].get(cut, 0) + 1
                
                if(len(jets['b_jet']) >= 2):
                    cut = f'At least 2 b_jets'    
                    for key in Cutflows.keys(): 
                        if label1 in key: Cutflows[key][cut] = Cutflows[key].get(cut, 0) + 1                
                
                if(len(jets['b_jet']) == 0):
                    label2 = 'non-resonant'
                elif(len(jets['b_jet']) == 1):
                    label2 = 'sLQ'
                elif(len(jets['b_jet']) == 2):
                    label2 = 'dLQ'
                else: continue
                
                label = f'{label1}_{label2}'  
                
                cut = f'{label2} selection'    
                Cutflows[label][cut] = Cutflows[label].get(cut, 0) + 1                
                
                if(leptons[0].DeltaR(leptons[1]) < 0.3): continue #DeltaR > 0.3
                cut = 'DeltaR > 0.3'
                Cutflows[label][cut] = Cutflows[label].get(cut,0) + 1
                
                MET = clasificator.get_met(event)
                MET.SetName('MET')
                particles = leptons + jets['b_jet'] + [MET]
                
                ST = 0
                for particle in particles: ST += particle.pt()
                
                HT = 0
                for particle in jets['l_jet']: HT += particle.pt()
                
                TLV = TLorentzVector(0,0,0,0)
                for particle in particles: TLV += particle.GetTLV()
                MT = TLV.Mt()
                
                Mass_invariant = (leptons[0].GetTLV() + leptons[1].GetTLV()).M()
                
                row = root_analysis.get_kinematics_row(particles)
                
                keylist = list(row.keys())
                for key in keylist: 
                    if ("Mass" in key): row.pop(key,None)
                
                row["sT(GeV)"] = ST
                row["hT(GeV)"] = HT
                row["mT(GeV)"] = MT
                row["light_jets_multiplicity"] = len(jets['l_jet'])
                name = leptons[0].Name + leptons[1].Name
                row[f"Mass_{{{name}}}(GeV)"] = Mass_invariant
                row[f"Q_{{{leptons[0].Name}}}Q_{{{leptons[1].Name}}}"] = leptons[0].Charge*leptons[1].Charge
                
                kinematic_variables[label].append(row)

        for key in Cutflows.keys(): root_analysis.generate_csv(kinematic_variables[key], os.path.join(csv_folder_path, f'{signal}_{key}.csv'))
        # !touch termino_{signal}.txt
        
    return {signal: Cutflows}

# %%
Masses = ['1250', '1500', '1750', '2000', '2250', '2500']
LQ_signals = ['LQ_LQ', 'Tau_LQ', 'Tau_Tau']
types = ['', '_wo_RHC', '_Betard_0_4']

signals = []

for signal_type in types:
    for signal in LQ_signals:
        for M in Masses:
            signals.append(f'{signal}_{M}{signal_type}')
        
signals = signals + ['ttbar', 'stop']

# %%
signals
# Out:
# ['LQ_LQ_1250',
#  'LQ_LQ_1500',
#  'LQ_LQ_1750',
#  'LQ_LQ_2000',
#  'LQ_LQ_2250',
#  'LQ_LQ_2500',
#  'Tau_LQ_1250',
#  'Tau_LQ_1500',
#  'Tau_LQ_1750',
#  'Tau_LQ_2000',
#  'Tau_LQ_2250',
#  'Tau_LQ_2500',
#  'Tau_Tau_1250',
#  'Tau_Tau_1500',
#  'Tau_Tau_1750',
#  'Tau_Tau_2000',
#  'Tau_Tau_2250',
#  'Tau_Tau_2500',
#  'LQ_LQ_1250_wo_RHC',
#  'LQ_LQ_1500_wo_RHC',
#  'LQ_LQ_1750_wo_RHC',
#  'LQ_LQ_2000_wo_RHC',
#  'LQ_LQ_2250_wo_RHC',
#  'LQ_LQ_2500_wo_RHC',
#  'Tau_LQ_1250_wo_RHC',
#  'Tau_LQ_1500_wo_RHC',
#  'Tau_LQ_1750_wo_RHC',
#  'Tau_LQ_2000_wo_RHC',
#  'Tau_LQ_2250_wo_RHC',
#  'Tau_LQ_2500_wo_RHC',
#  'Tau_Tau_1250_wo_RHC',
#  'Tau_Tau_1500_wo_RHC',
#  'Tau_Tau_1750_wo_RHC',
#  'Tau_Tau_2000_wo_RHC',
#  'Tau_Tau_2250_wo_RHC',
#  'Tau_Tau_2500_wo_RHC',
#  'LQ_LQ_1250_Betard_0_4',
#  'LQ_LQ_1500_Betard_0_4',
#  'LQ_LQ_1750_Betard_0_4',
#  'LQ_LQ_2000_Betard_0_4',
#  'LQ_LQ_2250_Betard_0_4',
#  'LQ_LQ_2500_Betard_0_4',
#  'Tau_LQ_1250_Betard_0_4',
#  'Tau_LQ_1500_Betard_0_4',
#  'Tau_LQ_1750_Betard_0_4',
#  'Tau_LQ_2000_Betard_0_4',
#  'Tau_LQ_2250_Betard_0_4',
#  'Tau_LQ_2500_Betard_0_4',
#  'Tau_Tau_1250_Betard_0_4',
#  'Tau_Tau_1500_Betard_0_4',
#  'Tau_Tau_1750_Betard_0_4',
#  'Tau_Tau_2000_Betard_0_4',
#  'Tau_Tau_2250_Betard_0_4',
#  'Tau_Tau_2500_Betard_0_4',
#  'ttbar',
#  'stop']

# %%
with Pool(6) as p:
    mapping = list(p.map(event_selection, signals))
#list(map(event_selection, signals))
# Out:
# LQ_LQ_2000 imported with 12 trees!
# /Madgraph_Simulations/LeptoQuarks/lq_lq/lq_lq_m_2000Tau_LQ_1250 imported with 12 trees!
# /Madgraph_Simulations/LeptoQuarks/tau_lq/tau_lq_m_1250Tau_LQ_2000 imported with 12 trees!
# /Madgraph_Simulations/LeptoQuarks/tau_lq/tau_lq_m_2000
#
#
# Tau_Tau_2000 imported with 12 trees!
# /Madgraph_Simulations/LeptoQuarks/Tau_Tau/M2000_gU1_8LQ_LQ_1250 imported with 12 trees!
# /Madgraph_Simulations/LeptoQuarks/lq_lq/lq_lq_m_1250
#
# Tau_Tau_1250 imported with 12 trees!
# /Madgraph_Simulations/LeptoQuarks/Tau_Tau/M1250_gU1_8
# LQ_LQ_1500 imported with 12 trees!
# /Madgraph_Simulations/LeptoQuarks/lq_lq/lq_lq_m_1500
# Tau_LQ_2250 imported with 12 trees!
# /Madgraph_Simulations/LeptoQuarks/tau_lq/tau_lq_m_2250
# Tau_LQ_1500 imported with 12 trees!
# /Madgraph_Simulations/LeptoQuarks/tau_lq/tau_lq_m_1500
# Tau_Tau_1500 imported with 12 trees!
# /Madgraph_Simulations/LeptoQuarks/Tau_Tau/M1500_gU1_8
# Tau_Tau_2250 imported with 12 trees!
# /Madgraph_Simulations/LeptoQuarks/Tau_Tau/M2250_gU1_8
# LQ_LQ_2250 imported with 12 trees!
# /Madgraph_Simulations/LeptoQuarks/lq_lq/lq_lq_m_2250
# Tau_LQ_1750 imported with 12 trees!
# /Madgraph_Simulations/LeptoQuarks/tau_lq/tau_lq_m_1750
# Tau_LQ_2500 imported with 12 trees!
# /Madgraph_Simulations/LeptoQuarks/tau_lq/tau_lq_m_2500
# Tau_Tau_1750 imported with 12 trees!
# /Madgraph_Simulations/LeptoQuarks/Tau_Tau/M1750_gU1_8
# LQ_LQ_1750 imported with 12 trees!
# /Madgraph_Simulations/LeptoQuarks/lq_lq/lq_lq_m_1750
# Tau_Tau_2500 imported with 12 trees!
# /Madgraph_Simulations/LeptoQuarks/Tau_Tau/M2500_gU1_8
# LQ_LQ_2500 imported with 12 trees!
# /Madgraph_Simulations/LeptoQuarks/lq_lq/lq_lq_m_2500
# LQ_LQ_1250_wo_RHC imported with 16 trees!
# /Madgraph_Simulations/LeptoQuarks/lq_lq_wo_RHC/M1250_gU1_8
# LQ_LQ_2000_wo_RHC imported with 16 trees!
# /Madgraph_Simulations/LeptoQuarks/lq_lq_wo_RHC/M2000_gU1_8
# Tau_LQ_1250_wo_RHC imported with 16 trees!
# /Madgraph_Simulations/LeptoQuarks/tau_lq_wo_RHC/M1250_gU1_8
# Tau_LQ_2000_wo_RHC imported with 16 trees!
# /Madgraph_Simulations/LeptoQuarks/tau_lq_wo_RHC/M2000_gU1_8
# Tau_Tau_1250_wo_RHC imported with 3 trees!
# /Madgraph_Simulations/LeptoQuarks/Tau_Tau_wo_RHC/M1250_gU1_8
# Tau_Tau_2000_wo_RHC imported with 3 trees!
# /Madgraph_Simulations/LeptoQuarks/Tau_Tau_wo_RHC/M2000_gU1_8
# Tau_Tau_1500_wo_RHC imported with 3 trees!
# /Madgraph_Simulations/LeptoQuarks/Tau_Tau_wo_RHC/M1500_gU1_8
# Tau_Tau_2250_wo_RHC imported with 3 trees!
# /Madgraph_Simulations/LeptoQuarks/Tau_Tau_wo_RHC/M2250_gU1_8
# Tau_LQ_1500_wo_RHC imported with 16 trees!
# /Madgraph_Simulations/LeptoQuarks/tau_lq_wo_RHC/M1500_gU1_8
# Tau_LQ_2250_wo_RHC imported with 16 trees!
# /Madgraph_Simulations/LeptoQuarks/tau_lq_wo_RHC/M2250_gU1_8
# LQ_LQ_1500_wo_RHC imported with 16 trees!
# /Madgraph_Simulations/LeptoQuarks/lq_lq_wo_RHC/M1500_gU1_8
# LQ_LQ_2250_wo_RHC imported with 16 trees!
# /Madgraph_Simulations/LeptoQuarks/lq_lq_wo_RHC/M2250_gU1_8
# Tau_Tau_1750_wo_RHC imported with 3 trees!
# /Madgraph_Simulations/LeptoQuarks/Tau_Tau_wo_RHC/M1750_gU1_8
# Tau_Tau_2500_wo_RHC imported with 3 trees!
# /Madgraph_Simulations/LeptoQuarks/Tau_Tau_wo_RHC/M2500_gU1_8
# LQ_LQ_1250_Betard_0_4 imported with 0 trees!
# /Madgraph_Simulations/LeptoQuarks/lq_lq_Betard_0_4/lq_lq_m_1250
# LQ_LQ_1500_Betard_0_4 imported with 0 trees!
# /Madgraph_Simulations/LeptoQuarks/lq_lq_Betard_0_4/lq_lq_m_1500
# LQ_LQ_1750_Betard_0_4 imported with 0 trees!
# /Madgraph_Simulations/LeptoQuarks/lq_lq_Betard_0_4/lq_lq_m_1750
# LQ_LQ_2000_Betard_0_4 imported with 0 trees!
# /Madgraph_Simulations/LeptoQuarks/lq_lq_Betard_0_4/lq_lq_m_2000
# LQ_LQ_2250_Betard_0_4 imported with 0 trees!
# /Madgraph_Simulations/LeptoQuarks/lq_lq_Betard_0_4/lq_lq_m_2250
# LQ_LQ_2500_Betard_0_4 imported with 0 trees!
# /Madgraph_Simulations/LeptoQuarks/lq_lq_Betard_0_4/lq_lq_m_2500
# Tau_LQ_1250_Betard_0_4 imported with 0 trees!
# /Madgraph_Simulations/LeptoQuarks/lq_ta_Betard_0_4/lq_ta_m_1250
# Tau_LQ_1500_Betard_0_4 imported with 0 trees!
# /Madgraph_Simulations/LeptoQuarks/lq_ta_Betard_0_4/lq_ta_m_1500
# Tau_LQ_1750_Betard_0_4 imported with 0 trees!
# /Madgraph_Simulations/LeptoQuarks/lq_ta_Betard_0_4/lq_ta_m_1750
# Tau_LQ_2000_Betard_0_4 imported with 0 trees!
# /Madgraph_Simulations/LeptoQuarks/lq_ta_Betard_0_4/lq_ta_m_2000
# Tau_LQ_2250_Betard_0_4 imported with 0 trees!
# /Madgraph_Simulations/LeptoQuarks/lq_ta_Betard_0_4/lq_ta_m_2250
# Tau_LQ_2500_Betard_0_4 imported with 0 trees!
# /Madgraph_Simulations/LeptoQuarks/lq_ta_Betard_0_4/lq_ta_m_2500
# Tau_Tau_1250_Betard_0_4 imported with 0 trees!
# /Madgraph_Simulations/LeptoQuarks/ta_ta_Betard_0_4/ta_ta_m_1250
# Tau_Tau_1500_Betard_0_4 imported with 0 trees!
# /Madgraph_Simulations/LeptoQuarks/ta_ta_Betard_0_4/ta_ta_m_1500
# Tau_Tau_1750_Betard_0_4 imported with 0 trees!
# /Madgraph_Simulations/LeptoQuarks/ta_ta_Betard_0_4/ta_ta_m_1750
# Tau_Tau_2000_Betard_0_4 imported with 0 trees!
# /Madgraph_Simulations/LeptoQuarks/ta_ta_Betard_0_4/ta_ta_m_2000
# Tau_Tau_2250_Betard_0_4 imported with 0 trees!
# /Madgraph_Simulations/LeptoQuarks/ta_ta_Betard_0_4/ta_ta_m_2250
# Tau_Tau_2500_Betard_0_4 imported with 0 trees!
# /Madgraph_Simulations/LeptoQuarks/ta_ta_Betard_0_4/ta_ta_m_2500
# ttbar imported with 500 trees!
# /Madgraph_Simulations/SM_Backgrounds/ttbar/
# Tau_LQ_1750_wo_RHC imported with 16 trees!
# /Madgraph_Simulations/LeptoQuarks/tau_lq_wo_RHC/M1750_gU1_8
# Tau_LQ_2500_wo_RHC imported with 16 trees!
# /Madgraph_Simulations/LeptoQuarks/tau_lq_wo_RHC/M2500_gU1_8
# stop imported with 232 trees!
# /Madgraph_Simulations/SM_Backgrounds/stop
# LQ_LQ_2500_wo_RHC imported with 16 trees!
# /Madgraph_Simulations/LeptoQuarks/lq_lq_wo_RHC/M2500_gU1_8
# LQ_LQ_1750_wo_RHC imported with 16 trees!
# /Madgraph_Simulations/LeptoQuarks/lq_lq_wo_RHC/M1750_gU1_8

# %%
labels = ['hadronic_non-resonant','hadronic_sLQ','hadronic_dLQ','semileptonic_non-resonant','semileptonic_sLQ','semileptonic_dLQ']

Dict_Cutflows = {}

for label in labels: Dict_Cutflows[label] = {}

for Cutflows_Signal_Directory in mapping:
    
    signal = list(Cutflows_Signal_Directory.keys())[0]
    
    for label in labels: Dict_Cutflows[label][signal] = Cutflows_Signal_Directory[signal][label]

# %%
csv_folder_path = f'/disco4/pheno_csv_files/Leptoquarks_Searches/'

Dict_DataFrames_Cutflows = {}

for key in Dict_Cutflows: 
    Dict_DataFrames_Cutflows[key] = pd.DataFrame.from_dict(Dict_Cutflows[key])
    carpeta = os.path.join(csv_folder_path, 'cutflows')
    try: os.mkdir(carpeta)
    except: pass
    Dict_DataFrames_Cutflows[key].to_csv(os.path.join(carpeta, f'{key}.csv'))

# %%
# !touch Delphes_Preselection_Efficiences_Analysis_termino.txt

# %%
for key in Dict_Cutflows: 
    carpeta = f'Cutflows_new'
    try: os.mkdir(carpeta)
    except: pass
    Dict_DataFrames_Cutflows[key].to_csv(os.path.join(carpeta, f'{key}.csv'))

# %%
Dict_Cutflows
# Out:
# {'hadronic_non-resonant': {'LQ_LQ_1250': {'XS': '0.0330183',
#    'All': 100000,
#    'Maximum 1 light lepton': 96624,
#    'At least 2 leptons': 16584,
#    'Exactly 2 leptons': 16075,
#    'hadronic selection': 6822,
#    'At least 2 b_jets': 3158,
#    'non-resonant selection': 841,
#    'DeltaR > 0.3': 841},
#   'LQ_LQ_1500': {'XS': '0.00654102',
#    'All': 100000,
#    'Maximum 1 light lepton': 96702,
#    'At least 2 leptons': 16625,
#    'Exactly 2 leptons': 16088,
#    'hadronic selection': 6821,
#    'At least 2 b_jets': 3070,
#    'non-resonant selection': 844,
#    'DeltaR > 0.3': 844},
#   'LQ_LQ_1750': {'XS': '0.001428408',
#    'All': 100000,
#    'Maximum 1 light lepton': 96571,
#    'At least 2 leptons': 16576,
#    'Exactly 2 leptons': 16086,
#    'hadronic selection': 6860,
#    'non-resonant selection': 895,
#    'DeltaR > 0.3': 895,
#    'At least 2 b_jets': 3131},
#   'LQ_LQ_2000': {'XS': '0.000331919',
#    'All': 100000,
#    'Maximum 1 light lepton': 96908,
#    'At least 2 leptons': 16301,
#    'Exactly 2 leptons': 15811,
#    'hadronic selection': 6782,
#    'At least 2 b_jets': 3083,
#    'non-resonant selection': 856,
#    'DeltaR > 0.3': 856},
#   'LQ_LQ_2250': {'XS': '8.02268e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 96761,
#    'At least 2 leptons': 16247,
#    'Exactly 2 leptons': 15690,
#    'hadronic selection': 6849,
#    'non-resonant selection': 870,
#    'DeltaR > 0.3': 870,
#    'At least 2 b_jets': 3079},
#   'LQ_LQ_2500': {'XS': '1.997652e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 96973,
#    'At least 2 leptons': 16106,
#    'Exactly 2 leptons': 15618,
#    'hadronic selection': 6740,
#    'At least 2 b_jets': 3049,
#    'non-resonant selection': 875,
#    'DeltaR > 0.3': 875},
#   'Tau_LQ_1250': {'XS': '0.02291',
#    'All': 100000,
#    'Maximum 1 light lepton': 95726,
#    'At least 2 leptons': 21894,
#    'Exactly 2 leptons': 21407,
#    'hadronic selection': 9124,
#    'non-resonant selection': 2555,
#    'DeltaR > 0.3': 2555,
#    'At least 2 b_jets': 1495},
#   'Tau_LQ_1500': {'XS': '0.006099',
#    'All': 100000,
#    'Maximum 1 light lepton': 95650,
#    'At least 2 leptons': 22084,
#    'Exactly 2 leptons': 21592,
#    'hadronic selection': 9100,
#    'At least 2 b_jets': 1555,
#    'non-resonant selection': 2443,
#    'DeltaR > 0.3': 2443},
#   'Tau_LQ_1750': {'XS': '0.001836',
#    'All': 100000,
#    'Maximum 1 light lepton': 95648,
#    'At least 2 leptons': 22490,
#    'Exactly 2 leptons': 21977,
#    'hadronic selection': 9387,
#    'non-resonant selection': 2552,
#    'DeltaR > 0.3': 2552,
#    'At least 2 b_jets': 1652},
#   'Tau_LQ_2000': {'XS': '0.0006038',
#    'All': 100000,
#    'Maximum 1 light lepton': 95450,
#    'At least 2 leptons': 22362,
#    'Exactly 2 leptons': 21911,
#    'hadronic selection': 9396,
#    'non-resonant selection': 2640,
#    'DeltaR > 0.3': 2640,
#    'At least 2 b_jets': 1586},
#   'Tau_LQ_2250': {'XS': '0.0002119',
#    'All': 100000,
#    'Maximum 1 light lepton': 95555,
#    'At least 2 leptons': 22355,
#    'Exactly 2 leptons': 21833,
#    'hadronic selection': 9507,
#    'non-resonant selection': 2736,
#    'DeltaR > 0.3': 2736,
#    'At least 2 b_jets': 1626},
#   'Tau_LQ_2500': {'XS': '7.806e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 95587,
#    'At least 2 leptons': 22332,
#    'Exactly 2 leptons': 21810,
#    'hadronic selection': 9320,
#    'non-resonant selection': 2676,
#    'DeltaR > 0.3': 2676,
#    'At least 2 b_jets': 1578},
#   'Tau_Tau_1250': {'XS': '0.147',
#    'All': 100000,
#    'Maximum 1 light lepton': 96785,
#    'At least 2 leptons': 19714,
#    'Exactly 2 leptons': 19603,
#    'hadronic selection': 9076,
#    'non-resonant selection': 6549,
#    'DeltaR > 0.3': 6549,
#    'At least 2 b_jets': 229},
#   'Tau_Tau_1500': {'XS': '0.07285',
#    'All': 100000,
#    'Maximum 1 light lepton': 96485,
#    'At least 2 leptons': 20159,
#    'Exactly 2 leptons': 20049,
#    'hadronic selection': 9169,
#    'non-resonant selection': 6520,
#    'DeltaR > 0.3': 6520,
#    'At least 2 b_jets': 276},
#   'Tau_Tau_1750': {'XS': '0.03964',
#    'All': 100000,
#    'Maximum 1 light lepton': 96511,
#    'At least 2 leptons': 20246,
#    'Exactly 2 leptons': 20131,
#    'hadronic selection': 9335,
#    'non-resonant selection': 6601,
#    'DeltaR > 0.3': 6601,
#    'At least 2 b_jets': 291},
#   'Tau_Tau_2000': {'XS': '0.02337',
#    'All': 100000,
#    'Maximum 1 light lepton': 96544,
#    'At least 2 leptons': 20696,
#    'Exactly 2 leptons': 20573,
#    'hadronic selection': 9377,
#    'non-resonant selection': 6681,
#    'DeltaR > 0.3': 6681,
#    'At least 2 b_jets': 266},
#   'Tau_Tau_2250': {'XS': '0.01466',
#    'All': 100000,
#    'Maximum 1 light lepton': 96457,
#    'At least 2 leptons': 20895,
#    'Exactly 2 leptons': 20776,
#    'hadronic selection': 9451,
#    'non-resonant selection': 6767,
#    'DeltaR > 0.3': 6767,
#    'At least 2 b_jets': 323},
#   'Tau_Tau_2500': {'XS': '0.009684',
#    'All': 100000,
#    'Maximum 1 light lepton': 96366,
#    'At least 2 leptons': 21061,
#    'Exactly 2 leptons': 20933,
#    'hadronic selection': 9521,
#    'non-resonant selection': 6791,
#    'DeltaR > 0.3': 6791,
#    'At least 2 b_jets': 256},
#   'LQ_LQ_1250_wo_RHC': {'XS': '0.03347837',
#    'All': 100000,
#    'Maximum 1 light lepton': 97588,
#    'At least 2 leptons': 11102,
#    'Exactly 2 leptons': 10789,
#    'hadronic selection': 4385,
#    'At least 2 b_jets': 1909,
#    'non-resonant selection': 597,
#    'DeltaR > 0.3': 597},
#   'LQ_LQ_1500_wo_RHC': {'XS': '0.006548228',
#    'All': 100000,
#    'Maximum 1 light lepton': 97605,
#    'At least 2 leptons': 11014,
#    'Exactly 2 leptons': 10686,
#    'hadronic selection': 4452,
#    'non-resonant selection': 680,
#    'DeltaR > 0.3': 680,
#    'At least 2 b_jets': 1845},
#   'LQ_LQ_1750_wo_RHC': {'XS': '0.0014225013',
#    'All': 100000,
#    'Maximum 1 light lepton': 97777,
#    'At least 2 leptons': 10788,
#    'Exactly 2 leptons': 10427,
#    'hadronic selection': 4286,
#    'non-resonant selection': 619,
#    'DeltaR > 0.3': 619,
#    'At least 2 b_jets': 1850},
#   'LQ_LQ_2000_wo_RHC': {'XS': '0.00033068328',
#    'All': 100000,
#    'Maximum 1 light lepton': 97881,
#    'At least 2 leptons': 10692,
#    'Exactly 2 leptons': 10395,
#    'hadronic selection': 4460,
#    'At least 2 b_jets': 1966,
#    'non-resonant selection': 639,
#    'DeltaR > 0.3': 639},
#   'LQ_LQ_2250_wo_RHC': {'XS': '7.9878115e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 97949,
#    'At least 2 leptons': 10468,
#    'Exactly 2 leptons': 10113,
#    'hadronic selection': 4317,
#    'At least 2 b_jets': 1858,
#    'non-resonant selection': 626,
#    'DeltaR > 0.3': 626},
#   'LQ_LQ_2500_wo_RHC': {'XS': '1.9879499e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 97966,
#    'At least 2 leptons': 10413,
#    'Exactly 2 leptons': 10071,
#    'hadronic selection': 4306,
#    'At least 2 b_jets': 1832,
#    'non-resonant selection': 645,
#    'DeltaR > 0.3': 645},
#   'Tau_LQ_1250_wo_RHC': {'XS': '0.0114448',
#    'All': 100000,
#    'Maximum 1 light lepton': 96104,
#    'At least 2 leptons': 18105,
#    'Exactly 2 leptons': 17670,
#    'hadronic selection': 7206,
#    'non-resonant selection': 2123,
#    'DeltaR > 0.3': 2123,
#    'At least 2 b_jets': 1165},
#   'Tau_LQ_1500_wo_RHC': {'XS': '0.00304724',
#    'All': 100000,
#    'Maximum 1 light lepton': 96197,
#    'At least 2 leptons': 18069,
#    'Exactly 2 leptons': 17654,
#    'hadronic selection': 7337,
#    'non-resonant selection': 2149,
#    'DeltaR > 0.3': 2149,
#    'At least 2 b_jets': 1261},
#   'Tau_LQ_1750_wo_RHC': {'XS': '0.00091653',
#    'All': 100000,
#    'Maximum 1 light lepton': 96356,
#    'At least 2 leptons': 18211,
#    'Exactly 2 leptons': 17793,
#    'hadronic selection': 7433,
#    'At least 2 b_jets': 1224,
#    'non-resonant selection': 2182,
#    'DeltaR > 0.3': 2182},
#   'Tau_LQ_2000_wo_RHC': {'XS': '0.00030121',
#    'All': 100000,
#    'Maximum 1 light lepton': 96393,
#    'At least 2 leptons': 17894,
#    'Exactly 2 leptons': 17486,
#    'hadronic selection': 7346,
#    'non-resonant selection': 2151,
#    'DeltaR > 0.3': 2151,
#    'At least 2 b_jets': 1163},
#   'Tau_LQ_2250_wo_RHC': {'XS': '0.00010571',
#    'All': 100000,
#    'Maximum 1 light lepton': 96422,
#    'At least 2 leptons': 17777,
#    'Exactly 2 leptons': 17356,
#    'hadronic selection': 7246,
#    'At least 2 b_jets': 1219,
#    'non-resonant selection': 2095,
#    'DeltaR > 0.3': 2095},
#   'Tau_LQ_2500_wo_RHC': {'XS': '3.895899e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 96428,
#    'At least 2 leptons': 17860,
#    'Exactly 2 leptons': 17433,
#    'hadronic selection': 7422,
#    'At least 2 b_jets': 1205,
#    'non-resonant selection': 2144,
#    'DeltaR > 0.3': 2144},
#   'Tau_Tau_1250_wo_RHC': {'XS': '0.01778',
#    'All': 100000,
#    'Maximum 1 light lepton': 96755,
#    'At least 2 leptons': 19990,
#    'Exactly 2 leptons': 19872,
#    'hadronic selection': 9196,
#    'non-resonant selection': 6602,
#    'DeltaR > 0.3': 6602,
#    'At least 2 b_jets': 254},
#   'Tau_Tau_1500_wo_RHC': {'XS': '0.008618',
#    'All': 100000,
#    'Maximum 1 light lepton': 96623,
#    'At least 2 leptons': 20532,
#    'Exactly 2 leptons': 20410,
#    'hadronic selection': 9188,
#    'non-resonant selection': 6615,
#    'DeltaR > 0.3': 6615,
#    'At least 2 b_jets': 266},
#   'Tau_Tau_1750_wo_RHC': {'XS': '0.004843',
#    'All': 100000,
#    'Maximum 1 light lepton': 96385,
#    'At least 2 leptons': 21371,
#    'Exactly 2 leptons': 21251,
#    'hadronic selection': 9577,
#    'non-resonant selection': 6679,
#    'DeltaR > 0.3': 6679,
#    'At least 2 b_jets': 295},
#   'Tau_Tau_2000_wo_RHC': {'XS': '0.002988',
#    'All': 100000,
#    'Maximum 1 light lepton': 96124,
#    'At least 2 leptons': 22014,
#    'Exactly 2 leptons': 21855,
#    'hadronic selection': 9841,
#    'non-resonant selection': 6980,
#    'DeltaR > 0.3': 6980,
#    'At least 2 b_jets': 299},
#   'Tau_Tau_2250_wo_RHC': {'XS': '0.002266',
#    'All': 100000,
#    'Maximum 1 light lepton': 95953,
#    'At least 2 leptons': 23055,
#    'Exactly 2 leptons': 22906,
#    'hadronic selection': 10176,
#    'non-resonant selection': 7166,
#    'DeltaR > 0.3': 7166,
#    'At least 2 b_jets': 328},
#   'Tau_Tau_2500_wo_RHC': {'XS': '0.001866',
#    'All': 100000,
#    'Maximum 1 light lepton': 95820,
#    'At least 2 leptons': 23415,
#    'Exactly 2 leptons': 23254,
#    'hadronic selection': 10207,
#    'non-resonant selection': 7159,
#    'DeltaR > 0.3': 7159,
#    'At least 2 b_jets': 325},
#   'LQ_LQ_1250_Betard_0_4': {'XS': '0.03346'},
#   'LQ_LQ_1500_Betard_0_4': {'XS': '0.006555'},
#   'LQ_LQ_1750_Betard_0_4': {'XS': '0.001426'},
#   'LQ_LQ_2000_Betard_0_4': {'XS': '0.0003305'},
#   'LQ_LQ_2250_Betard_0_4': {'XS': '7.989e-05'},
#   'LQ_LQ_2500_Betard_0_4': {'XS': '1.991e-05'},
#   'Tau_LQ_1250_Betard_0_4': {'XS': '0.01328'},
#   'Tau_LQ_1500_Betard_0_4': {'XS': '0.003534'},
#   'Tau_LQ_1750_Betard_0_4': {'XS': '0.001063'},
#   'Tau_LQ_2000_Betard_0_4': {'XS': '0.0003499'},
#   'Tau_LQ_2250_Betard_0_4': {'XS': '0.0001227'},
#   'Tau_LQ_2500_Betard_0_4': {'XS': '4.52e-05'},
#   'Tau_Tau_1250_Betard_0_4': {'XS': '0.03807'},
#   'Tau_Tau_1500_Betard_0_4': {'XS': '0.01864'},
#   'Tau_Tau_1750_Betard_0_4': {'XS': '0.01033'},
#   'Tau_Tau_2000_Betard_0_4': {'XS': '0.006297'},
#   'Tau_Tau_2250_Betard_0_4': {'XS': '0.004272'},
#   'Tau_Tau_2500_Betard_0_4': {'XS': '0.003105'},
#   'ttbar': {'XS': '504.696',
#    'All': 100000,
#    'Maximum 1 light lepton': 99025,
#    'At least 2 leptons': 607,
#    'Exactly 2 leptons': 602,
#    'hadronic selection': 73,
#    'At least 2 b_jets': 17,
#    'non-resonant selection': 23,
#    'DeltaR > 0.3': 23},
#   'stop': {'XS': '241.17',
#    'All': 100000,
#    'Maximum 1 light lepton': 99689,
#    'At least 2 leptons': 196,
#    'Exactly 2 leptons': 194,
#    'hadronic selection': 35,
#    'non-resonant selection': 18,
#    'DeltaR > 0.3': 18,
#    'At least 2 b_jets': 2}},
#  'hadronic_sLQ': {'LQ_LQ_1250': {'XS': '0.0330183',
#    'All': 100000,
#    'Maximum 1 light lepton': 96624,
#    'At least 2 leptons': 16584,
#    'Exactly 2 leptons': 16075,
#    'hadronic selection': 6822,
#    'At least 2 b_jets': 3158,
#    'sLQ selection': 2823,
#    'DeltaR > 0.3': 2823},
#   'LQ_LQ_1500': {'XS': '0.00654102',
#    'All': 100000,
#    'Maximum 1 light lepton': 96702,
#    'At least 2 leptons': 16625,
#    'Exactly 2 leptons': 16088,
#    'hadronic selection': 6821,
#    'sLQ selection': 2907,
#    'DeltaR > 0.3': 2907,
#    'At least 2 b_jets': 3070},
#   'LQ_LQ_1750': {'XS': '0.001428408',
#    'All': 100000,
#    'Maximum 1 light lepton': 96571,
#    'At least 2 leptons': 16576,
#    'Exactly 2 leptons': 16086,
#    'hadronic selection': 6860,
#    'sLQ selection': 2834,
#    'DeltaR > 0.3': 2834,
#    'At least 2 b_jets': 3131},
#   'LQ_LQ_2000': {'XS': '0.000331919',
#    'All': 100000,
#    'Maximum 1 light lepton': 96908,
#    'At least 2 leptons': 16301,
#    'Exactly 2 leptons': 15811,
#    'hadronic selection': 6782,
#    'sLQ selection': 2843,
#    'DeltaR > 0.3': 2843,
#    'At least 2 b_jets': 3083},
#   'LQ_LQ_2250': {'XS': '8.02268e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 96761,
#    'At least 2 leptons': 16247,
#    'Exactly 2 leptons': 15690,
#    'hadronic selection': 6849,
#    'sLQ selection': 2900,
#    'DeltaR > 0.3': 2900,
#    'At least 2 b_jets': 3079},
#   'LQ_LQ_2500': {'XS': '1.997652e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 96973,
#    'At least 2 leptons': 16106,
#    'Exactly 2 leptons': 15618,
#    'hadronic selection': 6740,
#    'At least 2 b_jets': 3049,
#    'sLQ selection': 2816,
#    'DeltaR > 0.3': 2816},
#   'Tau_LQ_1250': {'XS': '0.02291',
#    'All': 100000,
#    'Maximum 1 light lepton': 95726,
#    'At least 2 leptons': 21894,
#    'Exactly 2 leptons': 21407,
#    'hadronic selection': 9124,
#    'sLQ selection': 5074,
#    'DeltaR > 0.3': 5074,
#    'At least 2 b_jets': 1495},
#   'Tau_LQ_1500': {'XS': '0.006099',
#    'All': 100000,
#    'Maximum 1 light lepton': 95650,
#    'At least 2 leptons': 22084,
#    'Exactly 2 leptons': 21592,
#    'hadronic selection': 9100,
#    'sLQ selection': 5102,
#    'DeltaR > 0.3': 5102,
#    'At least 2 b_jets': 1555},
#   'Tau_LQ_1750': {'XS': '0.001836',
#    'All': 100000,
#    'Maximum 1 light lepton': 95648,
#    'At least 2 leptons': 22490,
#    'Exactly 2 leptons': 21977,
#    'hadronic selection': 9387,
#    'sLQ selection': 5183,
#    'DeltaR > 0.3': 5183,
#    'At least 2 b_jets': 1652},
#   'Tau_LQ_2000': {'XS': '0.0006038',
#    'All': 100000,
#    'Maximum 1 light lepton': 95450,
#    'At least 2 leptons': 22362,
#    'Exactly 2 leptons': 21911,
#    'hadronic selection': 9396,
#    'sLQ selection': 5170,
#    'DeltaR > 0.3': 5170,
#    'At least 2 b_jets': 1586},
#   'Tau_LQ_2250': {'XS': '0.0002119',
#    'All': 100000,
#    'Maximum 1 light lepton': 95555,
#    'At least 2 leptons': 22355,
#    'Exactly 2 leptons': 21833,
#    'hadronic selection': 9507,
#    'sLQ selection': 5145,
#    'DeltaR > 0.3': 5145,
#    'At least 2 b_jets': 1626},
#   'Tau_LQ_2500': {'XS': '7.806e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 95587,
#    'At least 2 leptons': 22332,
#    'Exactly 2 leptons': 21810,
#    'hadronic selection': 9320,
#    'sLQ selection': 5066,
#    'DeltaR > 0.3': 5066,
#    'At least 2 b_jets': 1578},
#   'Tau_Tau_1250': {'XS': '0.147',
#    'All': 100000,
#    'Maximum 1 light lepton': 96785,
#    'At least 2 leptons': 19714,
#    'Exactly 2 leptons': 19603,
#    'hadronic selection': 9076,
#    'sLQ selection': 2298,
#    'DeltaR > 0.3': 2298,
#    'At least 2 b_jets': 229},
#   'Tau_Tau_1500': {'XS': '0.07285',
#    'All': 100000,
#    'Maximum 1 light lepton': 96485,
#    'At least 2 leptons': 20159,
#    'Exactly 2 leptons': 20049,
#    'hadronic selection': 9169,
#    'sLQ selection': 2373,
#    'DeltaR > 0.3': 2373,
#    'At least 2 b_jets': 276},
#   'Tau_Tau_1750': {'XS': '0.03964',
#    'All': 100000,
#    'Maximum 1 light lepton': 96511,
#    'At least 2 leptons': 20246,
#    'Exactly 2 leptons': 20131,
#    'hadronic selection': 9335,
#    'sLQ selection': 2443,
#    'DeltaR > 0.3': 2443,
#    'At least 2 b_jets': 291},
#   'Tau_Tau_2000': {'XS': '0.02337',
#    'All': 100000,
#    'Maximum 1 light lepton': 96544,
#    'At least 2 leptons': 20696,
#    'Exactly 2 leptons': 20573,
#    'hadronic selection': 9377,
#    'sLQ selection': 2430,
#    'DeltaR > 0.3': 2430,
#    'At least 2 b_jets': 266},
#   'Tau_Tau_2250': {'XS': '0.01466',
#    'All': 100000,
#    'Maximum 1 light lepton': 96457,
#    'At least 2 leptons': 20895,
#    'Exactly 2 leptons': 20776,
#    'hadronic selection': 9451,
#    'At least 2 b_jets': 323,
#    'sLQ selection': 2361,
#    'DeltaR > 0.3': 2361},
#   'Tau_Tau_2500': {'XS': '0.009684',
#    'All': 100000,
#    'Maximum 1 light lepton': 96366,
#    'At least 2 leptons': 21061,
#    'Exactly 2 leptons': 20933,
#    'hadronic selection': 9521,
#    'sLQ selection': 2474,
#    'DeltaR > 0.3': 2474,
#    'At least 2 b_jets': 256},
#   'LQ_LQ_1250_wo_RHC': {'XS': '0.03347837',
#    'All': 100000,
#    'Maximum 1 light lepton': 97588,
#    'At least 2 leptons': 11102,
#    'Exactly 2 leptons': 10789,
#    'hadronic selection': 4385,
#    'sLQ selection': 1879,
#    'DeltaR > 0.3': 1879,
#    'At least 2 b_jets': 1909},
#   'LQ_LQ_1500_wo_RHC': {'XS': '0.006548228',
#    'All': 100000,
#    'Maximum 1 light lepton': 97605,
#    'At least 2 leptons': 11014,
#    'Exactly 2 leptons': 10686,
#    'hadronic selection': 4452,
#    'sLQ selection': 1927,
#    'DeltaR > 0.3': 1927,
#    'At least 2 b_jets': 1845},
#   'LQ_LQ_1750_wo_RHC': {'XS': '0.0014225013',
#    'All': 100000,
#    'Maximum 1 light lepton': 97777,
#    'At least 2 leptons': 10788,
#    'Exactly 2 leptons': 10427,
#    'hadronic selection': 4286,
#    'sLQ selection': 1817,
#    'DeltaR > 0.3': 1817,
#    'At least 2 b_jets': 1850},
#   'LQ_LQ_2000_wo_RHC': {'XS': '0.00033068328',
#    'All': 100000,
#    'Maximum 1 light lepton': 97881,
#    'At least 2 leptons': 10692,
#    'Exactly 2 leptons': 10395,
#    'hadronic selection': 4460,
#    'At least 2 b_jets': 1966,
#    'sLQ selection': 1855,
#    'DeltaR > 0.3': 1855},
#   'LQ_LQ_2250_wo_RHC': {'XS': '7.9878115e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 97949,
#    'At least 2 leptons': 10468,
#    'Exactly 2 leptons': 10113,
#    'hadronic selection': 4317,
#    'At least 2 b_jets': 1858,
#    'sLQ selection': 1833,
#    'DeltaR > 0.3': 1833},
#   'LQ_LQ_2500_wo_RHC': {'XS': '1.9879499e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 97966,
#    'At least 2 leptons': 10413,
#    'Exactly 2 leptons': 10071,
#    'hadronic selection': 4306,
#    'sLQ selection': 1829,
#    'DeltaR > 0.3': 1829,
#    'At least 2 b_jets': 1832},
#   'Tau_LQ_1250_wo_RHC': {'XS': '0.0114448',
#    'All': 100000,
#    'Maximum 1 light lepton': 96104,
#    'At least 2 leptons': 18105,
#    'Exactly 2 leptons': 17670,
#    'hadronic selection': 7206,
#    'sLQ selection': 3918,
#    'DeltaR > 0.3': 3918,
#    'At least 2 b_jets': 1165},
#   'Tau_LQ_1500_wo_RHC': {'XS': '0.00304724',
#    'All': 100000,
#    'Maximum 1 light lepton': 96197,
#    'At least 2 leptons': 18069,
#    'Exactly 2 leptons': 17654,
#    'hadronic selection': 7337,
#    'sLQ selection': 3927,
#    'DeltaR > 0.3': 3927,
#    'At least 2 b_jets': 1261},
#   'Tau_LQ_1750_wo_RHC': {'XS': '0.00091653',
#    'All': 100000,
#    'Maximum 1 light lepton': 96356,
#    'At least 2 leptons': 18211,
#    'Exactly 2 leptons': 17793,
#    'hadronic selection': 7433,
#    'At least 2 b_jets': 1224,
#    'sLQ selection': 4027,
#    'DeltaR > 0.3': 4027},
#   'Tau_LQ_2000_wo_RHC': {'XS': '0.00030121',
#    'All': 100000,
#    'Maximum 1 light lepton': 96393,
#    'At least 2 leptons': 17894,
#    'Exactly 2 leptons': 17486,
#    'hadronic selection': 7346,
#    'sLQ selection': 4032,
#    'DeltaR > 0.3': 4032,
#    'At least 2 b_jets': 1163},
#   'Tau_LQ_2250_wo_RHC': {'XS': '0.00010571',
#    'All': 100000,
#    'Maximum 1 light lepton': 96422,
#    'At least 2 leptons': 17777,
#    'Exactly 2 leptons': 17356,
#    'hadronic selection': 7246,
#    'At least 2 b_jets': 1219,
#    'sLQ selection': 3932,
#    'DeltaR > 0.3': 3932},
#   'Tau_LQ_2500_wo_RHC': {'XS': '3.895899e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 96428,
#    'At least 2 leptons': 17860,
#    'Exactly 2 leptons': 17433,
#    'hadronic selection': 7422,
#    'At least 2 b_jets': 1205,
#    'sLQ selection': 4073,
#    'DeltaR > 0.3': 4073},
#   'Tau_Tau_1250_wo_RHC': {'XS': '0.01778',
#    'All': 100000,
#    'Maximum 1 light lepton': 96755,
#    'At least 2 leptons': 19990,
#    'Exactly 2 leptons': 19872,
#    'hadronic selection': 9196,
#    'sLQ selection': 2340,
#    'DeltaR > 0.3': 2340,
#    'At least 2 b_jets': 254},
#   'Tau_Tau_1500_wo_RHC': {'XS': '0.008618',
#    'All': 100000,
#    'Maximum 1 light lepton': 96623,
#    'At least 2 leptons': 20532,
#    'Exactly 2 leptons': 20410,
#    'hadronic selection': 9188,
#    'sLQ selection': 2307,
#    'DeltaR > 0.3': 2307,
#    'At least 2 b_jets': 266},
#   'Tau_Tau_1750_wo_RHC': {'XS': '0.004843',
#    'All': 100000,
#    'Maximum 1 light lepton': 96385,
#    'At least 2 leptons': 21371,
#    'Exactly 2 leptons': 21251,
#    'hadronic selection': 9577,
#    'sLQ selection': 2603,
#    'DeltaR > 0.3': 2603,
#    'At least 2 b_jets': 295},
#   'Tau_Tau_2000_wo_RHC': {'XS': '0.002988',
#    'All': 100000,
#    'Maximum 1 light lepton': 96124,
#    'At least 2 leptons': 22014,
#    'Exactly 2 leptons': 21855,
#    'hadronic selection': 9841,
#    'sLQ selection': 2562,
#    'DeltaR > 0.3': 2562,
#    'At least 2 b_jets': 299},
#   'Tau_Tau_2250_wo_RHC': {'XS': '0.002266',
#    'All': 100000,
#    'Maximum 1 light lepton': 95953,
#    'At least 2 leptons': 23055,
#    'Exactly 2 leptons': 22906,
#    'hadronic selection': 10176,
#    'sLQ selection': 2682,
#    'DeltaR > 0.3': 2682,
#    'At least 2 b_jets': 328},
#   'Tau_Tau_2500_wo_RHC': {'XS': '0.001866',
#    'All': 100000,
#    'Maximum 1 light lepton': 95820,
#    'At least 2 leptons': 23415,
#    'Exactly 2 leptons': 23254,
#    'hadronic selection': 10207,
#    'sLQ selection': 2723,
#    'DeltaR > 0.3': 2723,
#    'At least 2 b_jets': 325},
#   'LQ_LQ_1250_Betard_0_4': {'XS': '0.03346'},
#   'LQ_LQ_1500_Betard_0_4': {'XS': '0.006555'},
#   'LQ_LQ_1750_Betard_0_4': {'XS': '0.001426'},
#   'LQ_LQ_2000_Betard_0_4': {'XS': '0.0003305'},
#   'LQ_LQ_2250_Betard_0_4': {'XS': '7.989e-05'},
#   'LQ_LQ_2500_Betard_0_4': {'XS': '1.991e-05'},
#   'Tau_LQ_1250_Betard_0_4': {'XS': '0.01328'},
#   'Tau_LQ_1500_Betard_0_4': {'XS': '0.003534'},
#   'Tau_LQ_1750_Betard_0_4': {'XS': '0.001063'},
#   'Tau_LQ_2000_Betard_0_4': {'XS': '0.0003499'},
#   'Tau_LQ_2250_Betard_0_4': {'XS': '0.0001227'},
#   'Tau_LQ_2500_Betard_0_4': {'XS': '4.52e-05'},
#   'Tau_Tau_1250_Betard_0_4': {'XS': '0.03807'},
#   'Tau_Tau_1500_Betard_0_4': {'XS': '0.01864'},
#   'Tau_Tau_1750_Betard_0_4': {'XS': '0.01033'},
#   'Tau_Tau_2000_Betard_0_4': {'XS': '0.006297'},
#   'Tau_Tau_2250_Betard_0_4': {'XS': '0.004272'},
#   'Tau_Tau_2500_Betard_0_4': {'XS': '0.003105'},
#   'ttbar': {'XS': '504.696',
#    'All': 100000,
#    'Maximum 1 light lepton': 99025,
#    'At least 2 leptons': 607,
#    'Exactly 2 leptons': 602,
#    'hadronic selection': 73,
#    'sLQ selection': 33,
#    'DeltaR > 0.3': 33,
#    'At least 2 b_jets': 17},
#   'stop': {'XS': '241.17',
#    'All': 100000,
#    'Maximum 1 light lepton': 99689,
#    'At least 2 leptons': 196,
#    'Exactly 2 leptons': 194,
#    'hadronic selection': 35,
#    'sLQ selection': 15,
#    'DeltaR > 0.3': 15,
#    'At least 2 b_jets': 2}},
#  'hadronic_dLQ': {'LQ_LQ_1250': {'XS': '0.0330183',
#    'All': 100000,
#    'Maximum 1 light lepton': 96624,
#    'At least 2 leptons': 16584,
#    'Exactly 2 leptons': 16075,
#    'hadronic selection': 6822,
#    'At least 2 b_jets': 3158,
#    'dLQ selection': 2699,
#    'DeltaR > 0.3': 2699},
#   'LQ_LQ_1500': {'XS': '0.00654102',
#    'All': 100000,
#    'Maximum 1 light lepton': 96702,
#    'At least 2 leptons': 16625,
#    'Exactly 2 leptons': 16088,
#    'hadronic selection': 6821,
#    'At least 2 b_jets': 3070,
#    'dLQ selection': 2605,
#    'DeltaR > 0.3': 2605},
#   'LQ_LQ_1750': {'XS': '0.001428408',
#    'All': 100000,
#    'Maximum 1 light lepton': 96571,
#    'At least 2 leptons': 16576,
#    'Exactly 2 leptons': 16086,
#    'hadronic selection': 6860,
#    'At least 2 b_jets': 3131,
#    'dLQ selection': 2638,
#    'DeltaR > 0.3': 2638},
#   'LQ_LQ_2000': {'XS': '0.000331919',
#    'All': 100000,
#    'Maximum 1 light lepton': 96908,
#    'At least 2 leptons': 16301,
#    'Exactly 2 leptons': 15811,
#    'hadronic selection': 6782,
#    'At least 2 b_jets': 3083,
#    'dLQ selection': 2547,
#    'DeltaR > 0.3': 2547},
#   'LQ_LQ_2250': {'XS': '8.02268e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 96761,
#    'At least 2 leptons': 16247,
#    'Exactly 2 leptons': 15690,
#    'hadronic selection': 6849,
#    'At least 2 b_jets': 3079,
#    'dLQ selection': 2598,
#    'DeltaR > 0.3': 2598},
#   'LQ_LQ_2500': {'XS': '1.997652e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 96973,
#    'At least 2 leptons': 16106,
#    'Exactly 2 leptons': 15618,
#    'hadronic selection': 6740,
#    'At least 2 b_jets': 3049,
#    'dLQ selection': 2557,
#    'DeltaR > 0.3': 2557},
#   'Tau_LQ_1250': {'XS': '0.02291',
#    'All': 100000,
#    'Maximum 1 light lepton': 95726,
#    'At least 2 leptons': 21894,
#    'Exactly 2 leptons': 21407,
#    'hadronic selection': 9124,
#    'At least 2 b_jets': 1495,
#    'dLQ selection': 1331,
#    'DeltaR > 0.3': 1331},
#   'Tau_LQ_1500': {'XS': '0.006099',
#    'All': 100000,
#    'Maximum 1 light lepton': 95650,
#    'At least 2 leptons': 22084,
#    'Exactly 2 leptons': 21592,
#    'hadronic selection': 9100,
#    'At least 2 b_jets': 1555,
#    'dLQ selection': 1402,
#    'DeltaR > 0.3': 1402},
#   'Tau_LQ_1750': {'XS': '0.001836',
#    'All': 100000,
#    'Maximum 1 light lepton': 95648,
#    'At least 2 leptons': 22490,
#    'Exactly 2 leptons': 21977,
#    'hadronic selection': 9387,
#    'At least 2 b_jets': 1652,
#    'dLQ selection': 1469,
#    'DeltaR > 0.3': 1469},
#   'Tau_LQ_2000': {'XS': '0.0006038',
#    'All': 100000,
#    'Maximum 1 light lepton': 95450,
#    'At least 2 leptons': 22362,
#    'Exactly 2 leptons': 21911,
#    'hadronic selection': 9396,
#    'At least 2 b_jets': 1586,
#    'dLQ selection': 1399,
#    'DeltaR > 0.3': 1399},
#   'Tau_LQ_2250': {'XS': '0.0002119',
#    'All': 100000,
#    'Maximum 1 light lepton': 95555,
#    'At least 2 leptons': 22355,
#    'Exactly 2 leptons': 21833,
#    'hadronic selection': 9507,
#    'At least 2 b_jets': 1626,
#    'dLQ selection': 1435,
#    'DeltaR > 0.3': 1435},
#   'Tau_LQ_2500': {'XS': '7.806e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 95587,
#    'At least 2 leptons': 22332,
#    'Exactly 2 leptons': 21810,
#    'hadronic selection': 9320,
#    'At least 2 b_jets': 1578,
#    'dLQ selection': 1398,
#    'DeltaR > 0.3': 1398},
#   'Tau_Tau_1250': {'XS': '0.147',
#    'All': 100000,
#    'Maximum 1 light lepton': 96785,
#    'At least 2 leptons': 19714,
#    'Exactly 2 leptons': 19603,
#    'hadronic selection': 9076,
#    'At least 2 b_jets': 229,
#    'dLQ selection': 220,
#    'DeltaR > 0.3': 220},
#   'Tau_Tau_1500': {'XS': '0.07285',
#    'All': 100000,
#    'Maximum 1 light lepton': 96485,
#    'At least 2 leptons': 20159,
#    'Exactly 2 leptons': 20049,
#    'hadronic selection': 9169,
#    'At least 2 b_jets': 276,
#    'dLQ selection': 267,
#    'DeltaR > 0.3': 267},
#   'Tau_Tau_1750': {'XS': '0.03964',
#    'All': 100000,
#    'Maximum 1 light lepton': 96511,
#    'At least 2 leptons': 20246,
#    'Exactly 2 leptons': 20131,
#    'hadronic selection': 9335,
#    'At least 2 b_jets': 291,
#    'dLQ selection': 277,
#    'DeltaR > 0.3': 277},
#   'Tau_Tau_2000': {'XS': '0.02337',
#    'All': 100000,
#    'Maximum 1 light lepton': 96544,
#    'At least 2 leptons': 20696,
#    'Exactly 2 leptons': 20573,
#    'hadronic selection': 9377,
#    'At least 2 b_jets': 266,
#    'dLQ selection': 249,
#    'DeltaR > 0.3': 249},
#   'Tau_Tau_2250': {'XS': '0.01466',
#    'All': 100000,
#    'Maximum 1 light lepton': 96457,
#    'At least 2 leptons': 20895,
#    'Exactly 2 leptons': 20776,
#    'hadronic selection': 9451,
#    'At least 2 b_jets': 323,
#    'dLQ selection': 312,
#    'DeltaR > 0.3': 312},
#   'Tau_Tau_2500': {'XS': '0.009684',
#    'All': 100000,
#    'Maximum 1 light lepton': 96366,
#    'At least 2 leptons': 21061,
#    'Exactly 2 leptons': 20933,
#    'hadronic selection': 9521,
#    'At least 2 b_jets': 256,
#    'dLQ selection': 247,
#    'DeltaR > 0.3': 247},
#   'LQ_LQ_1250_wo_RHC': {'XS': '0.03347837',
#    'All': 100000,
#    'Maximum 1 light lepton': 97588,
#    'At least 2 leptons': 11102,
#    'Exactly 2 leptons': 10789,
#    'hadronic selection': 4385,
#    'At least 2 b_jets': 1909,
#    'dLQ selection': 1623,
#    'DeltaR > 0.3': 1623},
#   'LQ_LQ_1500_wo_RHC': {'XS': '0.006548228',
#    'All': 100000,
#    'Maximum 1 light lepton': 97605,
#    'At least 2 leptons': 11014,
#    'Exactly 2 leptons': 10686,
#    'hadronic selection': 4452,
#    'At least 2 b_jets': 1845,
#    'dLQ selection': 1528,
#    'DeltaR > 0.3': 1528},
#   'LQ_LQ_1750_wo_RHC': {'XS': '0.0014225013',
#    'All': 100000,
#    'Maximum 1 light lepton': 97777,
#    'At least 2 leptons': 10788,
#    'Exactly 2 leptons': 10427,
#    'hadronic selection': 4286,
#    'At least 2 b_jets': 1850,
#    'dLQ selection': 1554,
#    'DeltaR > 0.3': 1554},
#   'LQ_LQ_2000_wo_RHC': {'XS': '0.00033068328',
#    'All': 100000,
#    'Maximum 1 light lepton': 97881,
#    'At least 2 leptons': 10692,
#    'Exactly 2 leptons': 10395,
#    'hadronic selection': 4460,
#    'At least 2 b_jets': 1966,
#    'dLQ selection': 1667,
#    'DeltaR > 0.3': 1667},
#   'LQ_LQ_2250_wo_RHC': {'XS': '7.9878115e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 97949,
#    'At least 2 leptons': 10468,
#    'Exactly 2 leptons': 10113,
#    'hadronic selection': 4317,
#    'At least 2 b_jets': 1858,
#    'dLQ selection': 1566,
#    'DeltaR > 0.3': 1566},
#   'LQ_LQ_2500_wo_RHC': {'XS': '1.9879499e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 97966,
#    'At least 2 leptons': 10413,
#    'Exactly 2 leptons': 10071,
#    'hadronic selection': 4306,
#    'At least 2 b_jets': 1832,
#    'dLQ selection': 1539,
#    'DeltaR > 0.3': 1539},
#   'Tau_LQ_1250_wo_RHC': {'XS': '0.0114448',
#    'All': 100000,
#    'Maximum 1 light lepton': 96104,
#    'At least 2 leptons': 18105,
#    'Exactly 2 leptons': 17670,
#    'hadronic selection': 7206,
#    'At least 2 b_jets': 1165,
#    'dLQ selection': 1053,
#    'DeltaR > 0.3': 1053},
#   'Tau_LQ_1500_wo_RHC': {'XS': '0.00304724',
#    'All': 100000,
#    'Maximum 1 light lepton': 96197,
#    'At least 2 leptons': 18069,
#    'Exactly 2 leptons': 17654,
#    'hadronic selection': 7337,
#    'At least 2 b_jets': 1261,
#    'dLQ selection': 1125,
#    'DeltaR > 0.3': 1125},
#   'Tau_LQ_1750_wo_RHC': {'XS': '0.00091653',
#    'All': 100000,
#    'Maximum 1 light lepton': 96356,
#    'At least 2 leptons': 18211,
#    'Exactly 2 leptons': 17793,
#    'hadronic selection': 7433,
#    'At least 2 b_jets': 1224,
#    'dLQ selection': 1097,
#    'DeltaR > 0.3': 1097},
#   'Tau_LQ_2000_wo_RHC': {'XS': '0.00030121',
#    'All': 100000,
#    'Maximum 1 light lepton': 96393,
#    'At least 2 leptons': 17894,
#    'Exactly 2 leptons': 17486,
#    'hadronic selection': 7346,
#    'At least 2 b_jets': 1163,
#    'dLQ selection': 1051,
#    'DeltaR > 0.3': 1051},
#   'Tau_LQ_2250_wo_RHC': {'XS': '0.00010571',
#    'All': 100000,
#    'Maximum 1 light lepton': 96422,
#    'At least 2 leptons': 17777,
#    'Exactly 2 leptons': 17356,
#    'hadronic selection': 7246,
#    'At least 2 b_jets': 1219,
#    'dLQ selection': 1087,
#    'DeltaR > 0.3': 1087},
#   'Tau_LQ_2500_wo_RHC': {'XS': '3.895899e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 96428,
#    'At least 2 leptons': 17860,
#    'Exactly 2 leptons': 17433,
#    'hadronic selection': 7422,
#    'At least 2 b_jets': 1205,
#    'dLQ selection': 1064,
#    'DeltaR > 0.3': 1064},
#   'Tau_Tau_1250_wo_RHC': {'XS': '0.01778',
#    'All': 100000,
#    'Maximum 1 light lepton': 96755,
#    'At least 2 leptons': 19990,
#    'Exactly 2 leptons': 19872,
#    'hadronic selection': 9196,
#    'At least 2 b_jets': 254,
#    'dLQ selection': 243,
#    'DeltaR > 0.3': 243},
#   'Tau_Tau_1500_wo_RHC': {'XS': '0.008618',
#    'All': 100000,
#    'Maximum 1 light lepton': 96623,
#    'At least 2 leptons': 20532,
#    'Exactly 2 leptons': 20410,
#    'hadronic selection': 9188,
#    'At least 2 b_jets': 266,
#    'dLQ selection': 250,
#    'DeltaR > 0.3': 250},
#   'Tau_Tau_1750_wo_RHC': {'XS': '0.004843',
#    'All': 100000,
#    'Maximum 1 light lepton': 96385,
#    'At least 2 leptons': 21371,
#    'Exactly 2 leptons': 21251,
#    'hadronic selection': 9577,
#    'At least 2 b_jets': 295,
#    'dLQ selection': 281,
#    'DeltaR > 0.3': 281},
#   'Tau_Tau_2000_wo_RHC': {'XS': '0.002988',
#    'All': 100000,
#    'Maximum 1 light lepton': 96124,
#    'At least 2 leptons': 22014,
#    'Exactly 2 leptons': 21855,
#    'hadronic selection': 9841,
#    'At least 2 b_jets': 299,
#    'dLQ selection': 280,
#    'DeltaR > 0.3': 280},
#   'Tau_Tau_2250_wo_RHC': {'XS': '0.002266',
#    'All': 100000,
#    'Maximum 1 light lepton': 95953,
#    'At least 2 leptons': 23055,
#    'Exactly 2 leptons': 22906,
#    'hadronic selection': 10176,
#    'At least 2 b_jets': 328,
#    'dLQ selection': 311,
#    'DeltaR > 0.3': 311},
#   'Tau_Tau_2500_wo_RHC': {'XS': '0.001866',
#    'All': 100000,
#    'Maximum 1 light lepton': 95820,
#    'At least 2 leptons': 23415,
#    'Exactly 2 leptons': 23254,
#    'hadronic selection': 10207,
#    'At least 2 b_jets': 325,
#    'dLQ selection': 318,
#    'DeltaR > 0.3': 318},
#   'LQ_LQ_1250_Betard_0_4': {'XS': '0.03346'},
#   'LQ_LQ_1500_Betard_0_4': {'XS': '0.006555'},
#   'LQ_LQ_1750_Betard_0_4': {'XS': '0.001426'},
#   'LQ_LQ_2000_Betard_0_4': {'XS': '0.0003305'},
#   'LQ_LQ_2250_Betard_0_4': {'XS': '7.989e-05'},
#   'LQ_LQ_2500_Betard_0_4': {'XS': '1.991e-05'},
#   'Tau_LQ_1250_Betard_0_4': {'XS': '0.01328'},
#   'Tau_LQ_1500_Betard_0_4': {'XS': '0.003534'},
#   'Tau_LQ_1750_Betard_0_4': {'XS': '0.001063'},
#   'Tau_LQ_2000_Betard_0_4': {'XS': '0.0003499'},
#   'Tau_LQ_2250_Betard_0_4': {'XS': '0.0001227'},
#   'Tau_LQ_2500_Betard_0_4': {'XS': '4.52e-05'},
#   'Tau_Tau_1250_Betard_0_4': {'XS': '0.03807'},
#   'Tau_Tau_1500_Betard_0_4': {'XS': '0.01864'},
#   'Tau_Tau_1750_Betard_0_4': {'XS': '0.01033'},
#   'Tau_Tau_2000_Betard_0_4': {'XS': '0.006297'},
#   'Tau_Tau_2250_Betard_0_4': {'XS': '0.004272'},
#   'Tau_Tau_2500_Betard_0_4': {'XS': '0.003105'},
#   'ttbar': {'XS': '504.696',
#    'All': 100000,
#    'Maximum 1 light lepton': 99025,
#    'At least 2 leptons': 607,
#    'Exactly 2 leptons': 602,
#    'hadronic selection': 73,
#    'At least 2 b_jets': 17,
#    'dLQ selection': 17,
#    'DeltaR > 0.3': 17},
#   'stop': {'XS': '241.17',
#    'All': 100000,
#    'Maximum 1 light lepton': 99689,
#    'At least 2 leptons': 196,
#    'Exactly 2 leptons': 194,
#    'hadronic selection': 35,
#    'At least 2 b_jets': 2,
#    'dLQ selection': 2,
#    'DeltaR > 0.3': 2}},
#  'semileptonic_non-resonant': {'LQ_LQ_1250': {'XS': '0.0330183',
#    'All': 100000,
#    'Maximum 1 light lepton': 96624,
#    'At least 2 leptons': 16584,
#    'Exactly 2 leptons': 16075,
#    'semileptonic selection': 9253,
#    'At least 2 b_jets': 4231,
#    'non-resonant selection': 1087,
#    'DeltaR > 0.3': 1087},
#   'LQ_LQ_1500': {'XS': '0.00654102',
#    'All': 100000,
#    'Maximum 1 light lepton': 96702,
#    'At least 2 leptons': 16625,
#    'Exactly 2 leptons': 16088,
#    'semileptonic selection': 9267,
#    'At least 2 b_jets': 4413,
#    'non-resonant selection': 1126,
#    'DeltaR > 0.3': 1126},
#   'LQ_LQ_1750': {'XS': '0.001428408',
#    'All': 100000,
#    'Maximum 1 light lepton': 96571,
#    'At least 2 leptons': 16576,
#    'Exactly 2 leptons': 16086,
#    'semileptonic selection': 9226,
#    'At least 2 b_jets': 4354,
#    'non-resonant selection': 1117,
#    'DeltaR > 0.3': 1117},
#   'LQ_LQ_2000': {'XS': '0.000331919',
#    'All': 100000,
#    'Maximum 1 light lepton': 96908,
#    'At least 2 leptons': 16301,
#    'Exactly 2 leptons': 15811,
#    'semileptonic selection': 9029,
#    'At least 2 b_jets': 4202,
#    'non-resonant selection': 1046,
#    'DeltaR > 0.3': 1046},
#   'LQ_LQ_2250': {'XS': '8.02268e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 96761,
#    'At least 2 leptons': 16247,
#    'Exactly 2 leptons': 15690,
#    'semileptonic selection': 8841,
#    'At least 2 b_jets': 4144,
#    'non-resonant selection': 1037,
#    'DeltaR > 0.3': 1037},
#   'LQ_LQ_2500': {'XS': '1.997652e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 96973,
#    'At least 2 leptons': 16106,
#    'Exactly 2 leptons': 15618,
#    'semileptonic selection': 8878,
#    'At least 2 b_jets': 4218,
#    'non-resonant selection': 1016,
#    'DeltaR > 0.3': 1016},
#   'Tau_LQ_1250': {'XS': '0.02291',
#    'All': 100000,
#    'Maximum 1 light lepton': 95726,
#    'At least 2 leptons': 21894,
#    'Exactly 2 leptons': 21407,
#    'semileptonic selection': 12283,
#    'At least 2 b_jets': 2117,
#    'non-resonant selection': 3382,
#    'DeltaR > 0.3': 3382},
#   'Tau_LQ_1500': {'XS': '0.006099',
#    'All': 100000,
#    'Maximum 1 light lepton': 95650,
#    'At least 2 leptons': 22084,
#    'Exactly 2 leptons': 21592,
#    'semileptonic selection': 12492,
#    'At least 2 b_jets': 2092,
#    'non-resonant selection': 3361,
#    'DeltaR > 0.3': 3361},
#   'Tau_LQ_1750': {'XS': '0.001836',
#    'All': 100000,
#    'Maximum 1 light lepton': 95648,
#    'At least 2 leptons': 22490,
#    'Exactly 2 leptons': 21977,
#    'semileptonic selection': 12590,
#    'At least 2 b_jets': 2240,
#    'non-resonant selection': 3397,
#    'DeltaR > 0.3': 3397},
#   'Tau_LQ_2000': {'XS': '0.0006038',
#    'All': 100000,
#    'Maximum 1 light lepton': 95450,
#    'At least 2 leptons': 22362,
#    'Exactly 2 leptons': 21911,
#    'semileptonic selection': 12515,
#    'non-resonant selection': 3408,
#    'DeltaR > 0.3': 3408,
#    'At least 2 b_jets': 2156},
#   'Tau_LQ_2250': {'XS': '0.0002119',
#    'All': 100000,
#    'Maximum 1 light lepton': 95555,
#    'At least 2 leptons': 22355,
#    'Exactly 2 leptons': 21833,
#    'semileptonic selection': 12326,
#    'At least 2 b_jets': 2054,
#    'non-resonant selection': 3385,
#    'DeltaR > 0.3': 3385},
#   'Tau_LQ_2500': {'XS': '7.806e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 95587,
#    'At least 2 leptons': 22332,
#    'Exactly 2 leptons': 21810,
#    'semileptonic selection': 12490,
#    'non-resonant selection': 3360,
#    'DeltaR > 0.3': 3360,
#    'At least 2 b_jets': 2113},
#   'Tau_Tau_1250': {'XS': '0.147',
#    'All': 100000,
#    'Maximum 1 light lepton': 96785,
#    'At least 2 leptons': 19714,
#    'Exactly 2 leptons': 19603,
#    'semileptonic selection': 10527,
#    'non-resonant selection': 7557,
#    'DeltaR > 0.3': 7557,
#    'At least 2 b_jets': 326},
#   'Tau_Tau_1500': {'XS': '0.07285',
#    'All': 100000,
#    'Maximum 1 light lepton': 96485,
#    'At least 2 leptons': 20159,
#    'Exactly 2 leptons': 20049,
#    'semileptonic selection': 10880,
#    'non-resonant selection': 7741,
#    'DeltaR > 0.3': 7741,
#    'At least 2 b_jets': 314},
#   'Tau_Tau_1750': {'XS': '0.03964',
#    'All': 100000,
#    'Maximum 1 light lepton': 96511,
#    'At least 2 leptons': 20246,
#    'Exactly 2 leptons': 20131,
#    'semileptonic selection': 10796,
#    'non-resonant selection': 7675,
#    'DeltaR > 0.3': 7675,
#    'At least 2 b_jets': 301},
#   'Tau_Tau_2000': {'XS': '0.02337',
#    'All': 100000,
#    'Maximum 1 light lepton': 96544,
#    'At least 2 leptons': 20696,
#    'Exactly 2 leptons': 20573,
#    'semileptonic selection': 11196,
#    'non-resonant selection': 7966,
#    'DeltaR > 0.3': 7966,
#    'At least 2 b_jets': 342},
#   'Tau_Tau_2250': {'XS': '0.01466',
#    'All': 100000,
#    'Maximum 1 light lepton': 96457,
#    'At least 2 leptons': 20895,
#    'Exactly 2 leptons': 20776,
#    'semileptonic selection': 11325,
#    'non-resonant selection': 8025,
#    'DeltaR > 0.3': 8025,
#    'At least 2 b_jets': 347},
#   'Tau_Tau_2500': {'XS': '0.009684',
#    'All': 100000,
#    'Maximum 1 light lepton': 96366,
#    'At least 2 leptons': 21061,
#    'Exactly 2 leptons': 20933,
#    'semileptonic selection': 11412,
#    'non-resonant selection': 8135,
#    'DeltaR > 0.3': 8135,
#    'At least 2 b_jets': 340},
#   'LQ_LQ_1250_wo_RHC': {'XS': '0.03347837',
#    'All': 100000,
#    'Maximum 1 light lepton': 97588,
#    'At least 2 leptons': 11102,
#    'Exactly 2 leptons': 10789,
#    'semileptonic selection': 6404,
#    'At least 2 b_jets': 2817,
#    'non-resonant selection': 862,
#    'DeltaR > 0.3': 862},
#   'LQ_LQ_1500_wo_RHC': {'XS': '0.006548228',
#    'All': 100000,
#    'Maximum 1 light lepton': 97605,
#    'At least 2 leptons': 11014,
#    'Exactly 2 leptons': 10686,
#    'semileptonic selection': 6234,
#    'At least 2 b_jets': 2846,
#    'non-resonant selection': 790,
#    'DeltaR > 0.3': 790},
#   'LQ_LQ_1750_wo_RHC': {'XS': '0.0014225013',
#    'All': 100000,
#    'Maximum 1 light lepton': 97777,
#    'At least 2 leptons': 10788,
#    'Exactly 2 leptons': 10427,
#    'semileptonic selection': 6141,
#    'At least 2 b_jets': 2757,
#    'non-resonant selection': 855,
#    'DeltaR > 0.3': 855},
#   'LQ_LQ_2000_wo_RHC': {'XS': '0.00033068328',
#    'All': 100000,
#    'Maximum 1 light lepton': 97881,
#    'At least 2 leptons': 10692,
#    'Exactly 2 leptons': 10395,
#    'semileptonic selection': 5935,
#    'At least 2 b_jets': 2692,
#    'non-resonant selection': 801,
#    'DeltaR > 0.3': 801},
#   'LQ_LQ_2250_wo_RHC': {'XS': '7.9878115e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 97949,
#    'At least 2 leptons': 10468,
#    'Exactly 2 leptons': 10113,
#    'semileptonic selection': 5796,
#    'At least 2 b_jets': 2566,
#    'non-resonant selection': 751,
#    'DeltaR > 0.3': 751},
#   'LQ_LQ_2500_wo_RHC': {'XS': '1.9879499e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 97966,
#    'At least 2 leptons': 10413,
#    'Exactly 2 leptons': 10071,
#    'semileptonic selection': 5765,
#    'non-resonant selection': 766,
#    'DeltaR > 0.3': 766,
#    'At least 2 b_jets': 2555},
#   'Tau_LQ_1250_wo_RHC': {'XS': '0.0114448',
#    'All': 100000,
#    'Maximum 1 light lepton': 96104,
#    'At least 2 leptons': 18105,
#    'Exactly 2 leptons': 17670,
#    'semileptonic selection': 10464,
#    'non-resonant selection': 2998,
#    'DeltaR > 0.3': 2998,
#    'At least 2 b_jets': 1711},
#   'Tau_LQ_1500_wo_RHC': {'XS': '0.00304724',
#    'All': 100000,
#    'Maximum 1 light lepton': 96197,
#    'At least 2 leptons': 18069,
#    'Exactly 2 leptons': 17654,
#    'semileptonic selection': 10317,
#    'non-resonant selection': 2885,
#    'DeltaR > 0.3': 2885,
#    'At least 2 b_jets': 1703},
#   'Tau_LQ_1750_wo_RHC': {'XS': '0.00091653',
#    'All': 100000,
#    'Maximum 1 light lepton': 96356,
#    'At least 2 leptons': 18211,
#    'Exactly 2 leptons': 17793,
#    'semileptonic selection': 10360,
#    'At least 2 b_jets': 1759,
#    'non-resonant selection': 2878,
#    'DeltaR > 0.3': 2878},
#   'Tau_LQ_2000_wo_RHC': {'XS': '0.00030121',
#    'All': 100000,
#    'Maximum 1 light lepton': 96393,
#    'At least 2 leptons': 17894,
#    'Exactly 2 leptons': 17486,
#    'semileptonic selection': 10140,
#    'non-resonant selection': 2876,
#    'DeltaR > 0.3': 2876,
#    'At least 2 b_jets': 1684},
#   'Tau_LQ_2250_wo_RHC': {'XS': '0.00010571',
#    'All': 100000,
#    'Maximum 1 light lepton': 96422,
#    'At least 2 leptons': 17777,
#    'Exactly 2 leptons': 17356,
#    'semileptonic selection': 10110,
#    'At least 2 b_jets': 1682,
#    'non-resonant selection': 2845,
#    'DeltaR > 0.3': 2845},
#   'Tau_LQ_2500_wo_RHC': {'XS': '3.895899e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 96428,
#    'At least 2 leptons': 17860,
#    'Exactly 2 leptons': 17433,
#    'semileptonic selection': 10011,
#    'At least 2 b_jets': 1698,
#    'non-resonant selection': 2721,
#    'DeltaR > 0.3': 2721},
#   'Tau_Tau_1250_wo_RHC': {'XS': '0.01778',
#    'All': 100000,
#    'Maximum 1 light lepton': 96755,
#    'At least 2 leptons': 19990,
#    'Exactly 2 leptons': 19872,
#    'semileptonic selection': 10676,
#    'non-resonant selection': 7646,
#    'DeltaR > 0.3': 7646,
#    'At least 2 b_jets': 327},
#   'Tau_Tau_1500_wo_RHC': {'XS': '0.008618',
#    'All': 100000,
#    'Maximum 1 light lepton': 96623,
#    'At least 2 leptons': 20532,
#    'Exactly 2 leptons': 20410,
#    'semileptonic selection': 11222,
#    'non-resonant selection': 7960,
#    'DeltaR > 0.3': 7960,
#    'At least 2 b_jets': 353},
#   'Tau_Tau_1750_wo_RHC': {'XS': '0.004843',
#    'All': 100000,
#    'Maximum 1 light lepton': 96385,
#    'At least 2 leptons': 21371,
#    'Exactly 2 leptons': 21251,
#    'semileptonic selection': 11674,
#    'non-resonant selection': 8209,
#    'DeltaR > 0.3': 8209,
#    'At least 2 b_jets': 381},
#   'Tau_Tau_2000_wo_RHC': {'XS': '0.002988',
#    'All': 100000,
#    'Maximum 1 light lepton': 96124,
#    'At least 2 leptons': 22014,
#    'Exactly 2 leptons': 21855,
#    'semileptonic selection': 12014,
#    'non-resonant selection': 8454,
#    'DeltaR > 0.3': 8454,
#    'At least 2 b_jets': 408},
#   'Tau_Tau_2250_wo_RHC': {'XS': '0.002266',
#    'All': 100000,
#    'Maximum 1 light lepton': 95953,
#    'At least 2 leptons': 23055,
#    'Exactly 2 leptons': 22906,
#    'semileptonic selection': 12730,
#    'non-resonant selection': 8812,
#    'DeltaR > 0.3': 8812,
#    'At least 2 b_jets': 423},
#   'Tau_Tau_2500_wo_RHC': {'XS': '0.001866',
#    'All': 100000,
#    'Maximum 1 light lepton': 95820,
#    'At least 2 leptons': 23415,
#    'Exactly 2 leptons': 23254,
#    'semileptonic selection': 13047,
#    'non-resonant selection': 9094,
#    'DeltaR > 0.3': 9094,
#    'At least 2 b_jets': 431},
#   'LQ_LQ_1250_Betard_0_4': {'XS': '0.03346'},
#   'LQ_LQ_1500_Betard_0_4': {'XS': '0.006555'},
#   'LQ_LQ_1750_Betard_0_4': {'XS': '0.001426'},
#   'LQ_LQ_2000_Betard_0_4': {'XS': '0.0003305'},
#   'LQ_LQ_2250_Betard_0_4': {'XS': '7.989e-05'},
#   'LQ_LQ_2500_Betard_0_4': {'XS': '1.991e-05'},
#   'Tau_LQ_1250_Betard_0_4': {'XS': '0.01328'},
#   'Tau_LQ_1500_Betard_0_4': {'XS': '0.003534'},
#   'Tau_LQ_1750_Betard_0_4': {'XS': '0.001063'},
#   'Tau_LQ_2000_Betard_0_4': {'XS': '0.0003499'},
#   'Tau_LQ_2250_Betard_0_4': {'XS': '0.0001227'},
#   'Tau_LQ_2500_Betard_0_4': {'XS': '4.52e-05'},
#   'Tau_Tau_1250_Betard_0_4': {'XS': '0.03807'},
#   'Tau_Tau_1500_Betard_0_4': {'XS': '0.01864'},
#   'Tau_Tau_1750_Betard_0_4': {'XS': '0.01033'},
#   'Tau_Tau_2000_Betard_0_4': {'XS': '0.006297'},
#   'Tau_Tau_2250_Betard_0_4': {'XS': '0.004272'},
#   'Tau_Tau_2500_Betard_0_4': {'XS': '0.003105'},
#   'ttbar': {'XS': '504.696',
#    'All': 100000,
#    'Maximum 1 light lepton': 99025,
#    'At least 2 leptons': 607,
#    'Exactly 2 leptons': 602,
#    'semileptonic selection': 529,
#    'non-resonant selection': 181,
#    'DeltaR > 0.3': 181,
#    'At least 2 b_jets': 110},
#   'stop': {'XS': '241.17',
#    'All': 100000,
#    'Maximum 1 light lepton': 99689,
#    'At least 2 leptons': 196,
#    'Exactly 2 leptons': 194,
#    'semileptonic selection': 159,
#    'non-resonant selection': 84,
#    'DeltaR > 0.3': 84,
#    'At least 2 b_jets': 9}},
#  'semileptonic_sLQ': {'LQ_LQ_1250': {'XS': '0.0330183',
#    'All': 100000,
#    'Maximum 1 light lepton': 96624,
#    'At least 2 leptons': 16584,
#    'Exactly 2 leptons': 16075,
#    'semileptonic selection': 9253,
#    'sLQ selection': 3935,
#    'DeltaR > 0.3': 3935,
#    'At least 2 b_jets': 4231},
#   'LQ_LQ_1500': {'XS': '0.00654102',
#    'All': 100000,
#    'Maximum 1 light lepton': 96702,
#    'At least 2 leptons': 16625,
#    'Exactly 2 leptons': 16088,
#    'semileptonic selection': 9267,
#    'sLQ selection': 3728,
#    'DeltaR > 0.3': 3728,
#    'At least 2 b_jets': 4413},
#   'LQ_LQ_1750': {'XS': '0.001428408',
#    'All': 100000,
#    'Maximum 1 light lepton': 96571,
#    'At least 2 leptons': 16576,
#    'Exactly 2 leptons': 16086,
#    'semileptonic selection': 9226,
#    'At least 2 b_jets': 4354,
#    'sLQ selection': 3755,
#    'DeltaR > 0.3': 3755},
#   'LQ_LQ_2000': {'XS': '0.000331919',
#    'All': 100000,
#    'Maximum 1 light lepton': 96908,
#    'At least 2 leptons': 16301,
#    'Exactly 2 leptons': 15811,
#    'semileptonic selection': 9029,
#    'sLQ selection': 3781,
#    'DeltaR > 0.3': 3781,
#    'At least 2 b_jets': 4202},
#   'LQ_LQ_2250': {'XS': '8.02268e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 96761,
#    'At least 2 leptons': 16247,
#    'Exactly 2 leptons': 15690,
#    'semileptonic selection': 8841,
#    'At least 2 b_jets': 4144,
#    'sLQ selection': 3660,
#    'DeltaR > 0.3': 3660},
#   'LQ_LQ_2500': {'XS': '1.997652e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 96973,
#    'At least 2 leptons': 16106,
#    'Exactly 2 leptons': 15618,
#    'semileptonic selection': 8878,
#    'At least 2 b_jets': 4218,
#    'sLQ selection': 3644,
#    'DeltaR > 0.3': 3644},
#   'Tau_LQ_1250': {'XS': '0.02291',
#    'All': 100000,
#    'Maximum 1 light lepton': 95726,
#    'At least 2 leptons': 21894,
#    'Exactly 2 leptons': 21407,
#    'semileptonic selection': 12283,
#    'At least 2 b_jets': 2117,
#    'sLQ selection': 6784,
#    'DeltaR > 0.3': 6784},
#   'Tau_LQ_1500': {'XS': '0.006099',
#    'All': 100000,
#    'Maximum 1 light lepton': 95650,
#    'At least 2 leptons': 22084,
#    'Exactly 2 leptons': 21592,
#    'semileptonic selection': 12492,
#    'sLQ selection': 7039,
#    'DeltaR > 0.3': 7039,
#    'At least 2 b_jets': 2092},
#   'Tau_LQ_1750': {'XS': '0.001836',
#    'All': 100000,
#    'Maximum 1 light lepton': 95648,
#    'At least 2 leptons': 22490,
#    'Exactly 2 leptons': 21977,
#    'semileptonic selection': 12590,
#    'At least 2 b_jets': 2240,
#    'sLQ selection': 6953,
#    'DeltaR > 0.3': 6953},
#   'Tau_LQ_2000': {'XS': '0.0006038',
#    'All': 100000,
#    'Maximum 1 light lepton': 95450,
#    'At least 2 leptons': 22362,
#    'Exactly 2 leptons': 21911,
#    'semileptonic selection': 12515,
#    'sLQ selection': 6951,
#    'DeltaR > 0.3': 6951,
# ...
#   'Tau_LQ_1250_wo_RHC': {'XS': '0.0114448',
#    'All': 100000,
#    'Maximum 1 light lepton': 96104,
#    'At least 2 leptons': 18105,
#    'Exactly 2 leptons': 17670,
#    'semileptonic selection': 10464,
#    'sLQ selection': 5755,
#    'DeltaR > 0.3': 5755,
#    'At least 2 b_jets': 1711},
#   'Tau_LQ_1500_wo_RHC': {'XS': '0.00304724',
#    'All': 100000,
#    'Maximum 1 light lepton': 96197,
#    'At least 2 leptons': 18069,
#    'Exactly 2 leptons': 17654,
#    'semileptonic selection': 10317,
#    'sLQ selection': 5729,
#    'DeltaR > 0.3': 5729,
#    'At least 2 b_jets': 1703},
#   'Tau_LQ_1750_wo_RHC': {'XS': '0.00091653',
#    'All': 100000,
#    'Maximum 1 light lepton': 96356,
#    'At least 2 leptons': 18211,
#    'Exactly 2 leptons': 17793,
#    'semileptonic selection': 10360,
#    'At least 2 b_jets': 1759,
#    'sLQ selection': 5723,
#    'DeltaR > 0.3': 5723},
#   'Tau_LQ_2000_wo_RHC': {'XS': '0.00030121',
#    'All': 100000,
#    'Maximum 1 light lepton': 96393,
#    'At least 2 leptons': 17894,
#    'Exactly 2 leptons': 17486,
#    'semileptonic selection': 10140,
#    'sLQ selection': 5580,
#    'DeltaR > 0.3': 5580,
#    'At least 2 b_jets': 1684},
#   'Tau_LQ_2250_wo_RHC': {'XS': '0.00010571',
#    'All': 100000,
#    'Maximum 1 light lepton': 96422,
#    'At least 2 leptons': 17777,
#    'Exactly 2 leptons': 17356,
#    'semileptonic selection': 10110,
#    'At least 2 b_jets': 1682,
#    'sLQ selection': 5583,
#    'DeltaR > 0.3': 5583},
#   'Tau_LQ_2500_wo_RHC': {'XS': '3.895899e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 96428,
#    'At least 2 leptons': 17860,
#    'Exactly 2 leptons': 17433,
#    'semileptonic selection': 10011,
#    'sLQ selection': 5592,
#    'DeltaR > 0.3': 5592,
#    'At least 2 b_jets': 1698},
#   'Tau_Tau_1250_wo_RHC': {'XS': '0.01778',
#    'All': 100000,
#    'Maximum 1 light lepton': 96755,
#    'At least 2 leptons': 19990,
#    'Exactly 2 leptons': 19872,
#    'semileptonic selection': 10676,
#    'sLQ selection': 2703,
#    'DeltaR > 0.3': 2703,
#    'At least 2 b_jets': 327},
#   'Tau_Tau_1500_wo_RHC': {'XS': '0.008618',
#    'All': 100000,
#    'Maximum 1 light lepton': 96623,
#    'At least 2 leptons': 20532,
#    'Exactly 2 leptons': 20410,
#    'semileptonic selection': 11222,
#    'sLQ selection': 2909,
#    'DeltaR > 0.3': 2909,
#    'At least 2 b_jets': 353},
#   'Tau_Tau_1750_wo_RHC': {'XS': '0.004843',
#    'All': 100000,
#    'Maximum 1 light lepton': 96385,
#    'At least 2 leptons': 21371,
#    'Exactly 2 leptons': 21251,
#    'semileptonic selection': 11674,
#    'sLQ selection': 3084,
#    'DeltaR > 0.3': 3084,
#    'At least 2 b_jets': 381},
#   'Tau_Tau_2000_wo_RHC': {'XS': '0.002988',
#    'All': 100000,
#    'Maximum 1 light lepton': 96124,
#    'At least 2 leptons': 22014,
#    'Exactly 2 leptons': 21855,
#    'semileptonic selection': 12014,
#    'sLQ selection': 3152,
#    'DeltaR > 0.3': 3152,
#    'At least 2 b_jets': 408},
#   'Tau_Tau_2250_wo_RHC': {'XS': '0.002266',
#    'All': 100000,
#    'Maximum 1 light lepton': 95953,
#    'At least 2 leptons': 23055,
#    'Exactly 2 leptons': 22906,
#    'semileptonic selection': 12730,
#    'sLQ selection': 3495,
#    'DeltaR > 0.3': 3495,
#    'At least 2 b_jets': 423},
#   'Tau_Tau_2500_wo_RHC': {'XS': '0.001866',
#    'All': 100000,
#    'Maximum 1 light lepton': 95820,
#    'At least 2 leptons': 23415,
#    'Exactly 2 leptons': 23254,
#    'semileptonic selection': 13047,
#    'sLQ selection': 3522,
#    'DeltaR > 0.3': 3522,
#    'At least 2 b_jets': 431},
#   'LQ_LQ_1250_Betard_0_4': {'XS': '0.03346'},
#   'LQ_LQ_1500_Betard_0_4': {'XS': '0.006555'},
#   'LQ_LQ_1750_Betard_0_4': {'XS': '0.001426'},
#   'LQ_LQ_2000_Betard_0_4': {'XS': '0.0003305'},
#   'LQ_LQ_2250_Betard_0_4': {'XS': '7.989e-05'},
#   'LQ_LQ_2500_Betard_0_4': {'XS': '1.991e-05'},
#   'Tau_LQ_1250_Betard_0_4': {'XS': '0.01328'},
#   'Tau_LQ_1500_Betard_0_4': {'XS': '0.003534'},
#   'Tau_LQ_1750_Betard_0_4': {'XS': '0.001063'},
#   'Tau_LQ_2000_Betard_0_4': {'XS': '0.0003499'},
#   'Tau_LQ_2250_Betard_0_4': {'XS': '0.0001227'},
#   'Tau_LQ_2500_Betard_0_4': {'XS': '4.52e-05'},
#   'Tau_Tau_1250_Betard_0_4': {'XS': '0.03807'},
#   'Tau_Tau_1500_Betard_0_4': {'XS': '0.01864'},
#   'Tau_Tau_1750_Betard_0_4': {'XS': '0.01033'},
#   'Tau_Tau_2000_Betard_0_4': {'XS': '0.006297'},
#   'Tau_Tau_2250_Betard_0_4': {'XS': '0.004272'},
#   'Tau_Tau_2500_Betard_0_4': {'XS': '0.003105'},
#   'ttbar': {'XS': '504.696',
#    'All': 100000,
#    'Maximum 1 light lepton': 99025,
#    'At least 2 leptons': 607,
#    'Exactly 2 leptons': 602,
#    'semileptonic selection': 529,
#    'sLQ selection': 238,
#    'DeltaR > 0.3': 238,
#    'At least 2 b_jets': 110},
#   'stop': {'XS': '241.17',
#    'All': 100000,
#    'Maximum 1 light lepton': 99689,
#    'At least 2 leptons': 196,
#    'Exactly 2 leptons': 194,
#    'semileptonic selection': 159,
#    'sLQ selection': 66,
#    'DeltaR > 0.3': 66,
#    'At least 2 b_jets': 9}},
#  'semileptonic_dLQ': {'LQ_LQ_1250': {'XS': '0.0330183',
#    'All': 100000,
#    'Maximum 1 light lepton': 96624,
#    'At least 2 leptons': 16584,
#    'Exactly 2 leptons': 16075,
#    'semileptonic selection': 9253,
#    'At least 2 b_jets': 4231,
#    'dLQ selection': 3620,
#    'DeltaR > 0.3': 3620},
#   'LQ_LQ_1500': {'XS': '0.00654102',
#    'All': 100000,
#    'Maximum 1 light lepton': 96702,
#    'At least 2 leptons': 16625,
#    'Exactly 2 leptons': 16088,
#    'semileptonic selection': 9267,
#    'At least 2 b_jets': 4413,
#    'dLQ selection': 3794,
#    'DeltaR > 0.3': 3794},
#   'LQ_LQ_1750': {'XS': '0.001428408',
#    'All': 100000,
#    'Maximum 1 light lepton': 96571,
#    'At least 2 leptons': 16576,
#    'Exactly 2 leptons': 16086,
#    'semileptonic selection': 9226,
#    'At least 2 b_jets': 4354,
#    'dLQ selection': 3713,
#    'DeltaR > 0.3': 3713},
#   'LQ_LQ_2000': {'XS': '0.000331919',
#    'All': 100000,
#    'Maximum 1 light lepton': 96908,
#    'At least 2 leptons': 16301,
#    'Exactly 2 leptons': 15811,
#    'semileptonic selection': 9029,
#    'At least 2 b_jets': 4202,
#    'dLQ selection': 3543,
#    'DeltaR > 0.3': 3543},
#   'LQ_LQ_2250': {'XS': '8.02268e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 96761,
#    'At least 2 leptons': 16247,
#    'Exactly 2 leptons': 15690,
#    'semileptonic selection': 8841,
#    'At least 2 b_jets': 4144,
#    'dLQ selection': 3532,
#    'DeltaR > 0.3': 3532},
#   'LQ_LQ_2500': {'XS': '1.997652e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 96973,
#    'At least 2 leptons': 16106,
#    'Exactly 2 leptons': 15618,
#    'semileptonic selection': 8878,
#    'At least 2 b_jets': 4218,
#    'dLQ selection': 3491,
#    'DeltaR > 0.3': 3491},
#   'Tau_LQ_1250': {'XS': '0.02291',
#    'All': 100000,
#    'Maximum 1 light lepton': 95726,
#    'At least 2 leptons': 21894,
#    'Exactly 2 leptons': 21407,
#    'semileptonic selection': 12283,
#    'At least 2 b_jets': 2117,
#    'dLQ selection': 1884,
#    'DeltaR > 0.3': 1884},
#   'Tau_LQ_1500': {'XS': '0.006099',
#    'All': 100000,
#    'Maximum 1 light lepton': 95650,
#    'At least 2 leptons': 22084,
#    'Exactly 2 leptons': 21592,
#    'semileptonic selection': 12492,
#    'At least 2 b_jets': 2092,
#    'dLQ selection': 1882,
#    'DeltaR > 0.3': 1882},
#   'Tau_LQ_1750': {'XS': '0.001836',
#    'All': 100000,
#    'Maximum 1 light lepton': 95648,
#    'At least 2 leptons': 22490,
#    'Exactly 2 leptons': 21977,
#    'semileptonic selection': 12590,
#    'At least 2 b_jets': 2240,
#    'dLQ selection': 2008,
#    'DeltaR > 0.3': 2008},
#   'Tau_LQ_2000': {'XS': '0.0006038',
#    'All': 100000,
#    'Maximum 1 light lepton': 95450,
#    'At least 2 leptons': 22362,
#    'Exactly 2 leptons': 21911,
#    'semileptonic selection': 12515,
#    'At least 2 b_jets': 2156,
#    'dLQ selection': 1903,
#    'DeltaR > 0.3': 1903},
#   'Tau_LQ_2250': {'XS': '0.0002119',
#    'All': 100000,
#    'Maximum 1 light lepton': 95555,
#    'At least 2 leptons': 22355,
#    'Exactly 2 leptons': 21833,
#    'semileptonic selection': 12326,
#    'At least 2 b_jets': 2054,
#    'dLQ selection': 1818,
#    'DeltaR > 0.3': 1818},
#   'Tau_LQ_2500': {'XS': '7.806e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 95587,
#    'At least 2 leptons': 22332,
#    'Exactly 2 leptons': 21810,
#    'semileptonic selection': 12490,
#    'At least 2 b_jets': 2113,
#    'dLQ selection': 1878,
#    'DeltaR > 0.3': 1878},
#   'Tau_Tau_1250': {'XS': '0.147',
#    'All': 100000,
#    'Maximum 1 light lepton': 96785,
#    'At least 2 leptons': 19714,
#    'Exactly 2 leptons': 19603,
#    'semileptonic selection': 10527,
#    'At least 2 b_jets': 326,
#    'dLQ selection': 312,
#    'DeltaR > 0.3': 312},
#   'Tau_Tau_1500': {'XS': '0.07285',
#    'All': 100000,
#    'Maximum 1 light lepton': 96485,
#    'At least 2 leptons': 20159,
#    'Exactly 2 leptons': 20049,
#    'semileptonic selection': 10880,
#    'At least 2 b_jets': 314,
#    'dLQ selection': 298,
#    'DeltaR > 0.3': 298},
#   'Tau_Tau_1750': {'XS': '0.03964',
#    'All': 100000,
#    'Maximum 1 light lepton': 96511,
#    'At least 2 leptons': 20246,
#    'Exactly 2 leptons': 20131,
#    'semileptonic selection': 10796,
#    'At least 2 b_jets': 301,
#    'dLQ selection': 288,
#    'DeltaR > 0.3': 288},
#   'Tau_Tau_2000': {'XS': '0.02337',
#    'All': 100000,
#    'Maximum 1 light lepton': 96544,
#    'At least 2 leptons': 20696,
#    'Exactly 2 leptons': 20573,
#    'semileptonic selection': 11196,
#    'At least 2 b_jets': 342,
#    'dLQ selection': 324,
#    'DeltaR > 0.3': 324},
#   'Tau_Tau_2250': {'XS': '0.01466',
#    'All': 100000,
#    'Maximum 1 light lepton': 96457,
#    'At least 2 leptons': 20895,
#    'Exactly 2 leptons': 20776,
#    'semileptonic selection': 11325,
#    'At least 2 b_jets': 347,
#    'dLQ selection': 332,
#    'DeltaR > 0.3': 332},
#   'Tau_Tau_2500': {'XS': '0.009684',
#    'All': 100000,
#    'Maximum 1 light lepton': 96366,
#    'At least 2 leptons': 21061,
#    'Exactly 2 leptons': 20933,
#    'semileptonic selection': 11412,
#    'At least 2 b_jets': 340,
#    'dLQ selection': 333,
#    'DeltaR > 0.3': 333},
#   'LQ_LQ_1250_wo_RHC': {'XS': '0.03347837',
#    'All': 100000,
#    'Maximum 1 light lepton': 97588,
#    'At least 2 leptons': 11102,
#    'Exactly 2 leptons': 10789,
#    'semileptonic selection': 6404,
#    'At least 2 b_jets': 2817,
#    'dLQ selection': 2394,
#    'DeltaR > 0.3': 2394},
#   'LQ_LQ_1500_wo_RHC': {'XS': '0.006548228',
#    'All': 100000,
#    'Maximum 1 light lepton': 97605,
#    'At least 2 leptons': 11014,
#    'Exactly 2 leptons': 10686,
#    'semileptonic selection': 6234,
#    'At least 2 b_jets': 2846,
#    'dLQ selection': 2441,
#    'DeltaR > 0.3': 2441},
#   'LQ_LQ_1750_wo_RHC': {'XS': '0.0014225013',
#    'All': 100000,
#    'Maximum 1 light lepton': 97777,
#    'At least 2 leptons': 10788,
#    'Exactly 2 leptons': 10427,
#    'semileptonic selection': 6141,
#    'At least 2 b_jets': 2757,
#    'dLQ selection': 2354,
#    'DeltaR > 0.3': 2354},
#   'LQ_LQ_2000_wo_RHC': {'XS': '0.00033068328',
#    'All': 100000,
#    'Maximum 1 light lepton': 97881,
#    'At least 2 leptons': 10692,
#    'Exactly 2 leptons': 10395,
#    'semileptonic selection': 5935,
#    'At least 2 b_jets': 2692,
#    'dLQ selection': 2312,
#    'DeltaR > 0.3': 2312},
#   'LQ_LQ_2250_wo_RHC': {'XS': '7.9878115e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 97949,
#    'At least 2 leptons': 10468,
#    'Exactly 2 leptons': 10113,
#    'semileptonic selection': 5796,
#    'At least 2 b_jets': 2566,
#    'dLQ selection': 2148,
#    'DeltaR > 0.3': 2148},
#   'LQ_LQ_2500_wo_RHC': {'XS': '1.9879499e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 97966,
#    'At least 2 leptons': 10413,
#    'Exactly 2 leptons': 10071,
#    'semileptonic selection': 5765,
#    'At least 2 b_jets': 2555,
#    'dLQ selection': 2160,
#    'DeltaR > 0.3': 2160},
#   'Tau_LQ_1250_wo_RHC': {'XS': '0.0114448',
#    'All': 100000,
#    'Maximum 1 light lepton': 96104,
#    'At least 2 leptons': 18105,
#    'Exactly 2 leptons': 17670,
#    'semileptonic selection': 10464,
#    'At least 2 b_jets': 1711,
#    'dLQ selection': 1537,
#    'DeltaR > 0.3': 1537},
#   'Tau_LQ_1500_wo_RHC': {'XS': '0.00304724',
#    'All': 100000,
#    'Maximum 1 light lepton': 96197,
#    'At least 2 leptons': 18069,
#    'Exactly 2 leptons': 17654,
#    'semileptonic selection': 10317,
#    'At least 2 b_jets': 1703,
#    'dLQ selection': 1522,
#    'DeltaR > 0.3': 1522},
#   'Tau_LQ_1750_wo_RHC': {'XS': '0.00091653',
#    'All': 100000,
#    'Maximum 1 light lepton': 96356,
#    'At least 2 leptons': 18211,
#    'Exactly 2 leptons': 17793,
#    'semileptonic selection': 10360,
#    'At least 2 b_jets': 1759,
#    'dLQ selection': 1593,
#    'DeltaR > 0.3': 1593},
#   'Tau_LQ_2000_wo_RHC': {'XS': '0.00030121',
#    'All': 100000,
#    'Maximum 1 light lepton': 96393,
#    'At least 2 leptons': 17894,
#    'Exactly 2 leptons': 17486,
#    'semileptonic selection': 10140,
#    'At least 2 b_jets': 1684,
#    'dLQ selection': 1504,
#    'DeltaR > 0.3': 1504},
#   'Tau_LQ_2250_wo_RHC': {'XS': '0.00010571',
#    'All': 100000,
#    'Maximum 1 light lepton': 96422,
#    'At least 2 leptons': 17777,
#    'Exactly 2 leptons': 17356,
#    'semileptonic selection': 10110,
#    'At least 2 b_jets': 1682,
#    'dLQ selection': 1494,
#    'DeltaR > 0.3': 1494},
#   'Tau_LQ_2500_wo_RHC': {'XS': '3.895899e-05',
#    'All': 100000,
#    'Maximum 1 light lepton': 96428,
#    'At least 2 leptons': 17860,
#    'Exactly 2 leptons': 17433,
#    'semileptonic selection': 10011,
#    'At least 2 b_jets': 1698,
#    'dLQ selection': 1507,
#    'DeltaR > 0.3': 1507},
#   'Tau_Tau_1250_wo_RHC': {'XS': '0.01778',
#    'All': 100000,
#    'Maximum 1 light lepton': 96755,
#    'At least 2 leptons': 19990,
#    'Exactly 2 leptons': 19872,
#    'semileptonic selection': 10676,
#    'At least 2 b_jets': 327,
#    'dLQ selection': 313,
#    'DeltaR > 0.3': 313},
#   'Tau_Tau_1500_wo_RHC': {'XS': '0.008618',
#    'All': 100000,
#    'Maximum 1 light lepton': 96623,
#    'At least 2 leptons': 20532,
#    'Exactly 2 leptons': 20410,
#    'semileptonic selection': 11222,
#    'At least 2 b_jets': 353,
#    'dLQ selection': 337,
#    'DeltaR > 0.3': 337},
#   'Tau_Tau_1750_wo_RHC': {'XS': '0.004843',
#    'All': 100000,
#    'Maximum 1 light lepton': 96385,
#    'At least 2 leptons': 21371,
#    'Exactly 2 leptons': 21251,
#    'semileptonic selection': 11674,
#    'At least 2 b_jets': 381,
#    'dLQ selection': 364,
#    'DeltaR > 0.3': 364},
#   'Tau_Tau_2000_wo_RHC': {'XS': '0.002988',
#    'All': 100000,
#    'Maximum 1 light lepton': 96124,
#    'At least 2 leptons': 22014,
#    'Exactly 2 leptons': 21855,
#    'semileptonic selection': 12014,
#    'At least 2 b_jets': 408,
#    'dLQ selection': 395,
#    'DeltaR > 0.3': 395},
#   'Tau_Tau_2250_wo_RHC': {'XS': '0.002266',
#    'All': 100000,
#    'Maximum 1 light lepton': 95953,
#    'At least 2 leptons': 23055,
#    'Exactly 2 leptons': 22906,
#    'semileptonic selection': 12730,
#    'At least 2 b_jets': 423,
#    'dLQ selection': 405,
#    'DeltaR > 0.3': 405},
#   'Tau_Tau_2500_wo_RHC': {'XS': '0.001866',
#    'All': 100000,
#    'Maximum 1 light lepton': 95820,
#    'At least 2 leptons': 23415,
#    'Exactly 2 leptons': 23254,
#    'semileptonic selection': 13047,
#    'At least 2 b_jets': 431,
#    'dLQ selection': 410,
#    'DeltaR > 0.3': 410},
#   'LQ_LQ_1250_Betard_0_4': {'XS': '0.03346'},
#   'LQ_LQ_1500_Betard_0_4': {'XS': '0.006555'},
#   'LQ_LQ_1750_Betard_0_4': {'XS': '0.001426'},
#   'LQ_LQ_2000_Betard_0_4': {'XS': '0.0003305'},
#   'LQ_LQ_2250_Betard_0_4': {'XS': '7.989e-05'},
#   'LQ_LQ_2500_Betard_0_4': {'XS': '1.991e-05'},
#   'Tau_LQ_1250_Betard_0_4': {'XS': '0.01328'},
#   'Tau_LQ_1500_Betard_0_4': {'XS': '0.003534'},
#   'Tau_LQ_1750_Betard_0_4': {'XS': '0.001063'},
#   'Tau_LQ_2000_Betard_0_4': {'XS': '0.0003499'},
#   'Tau_LQ_2250_Betard_0_4': {'XS': '0.0001227'},
#   'Tau_LQ_2500_Betard_0_4': {'XS': '4.52e-05'},
#   'Tau_Tau_1250_Betard_0_4': {'XS': '0.03807'},
#   'Tau_Tau_1500_Betard_0_4': {'XS': '0.01864'},
#   'Tau_Tau_1750_Betard_0_4': {'XS': '0.01033'},
#   'Tau_Tau_2000_Betard_0_4': {'XS': '0.006297'},
#   'Tau_Tau_2250_Betard_0_4': {'XS': '0.004272'},
#   'Tau_Tau_2500_Betard_0_4': {'XS': '0.003105'},
#   'ttbar': {'XS': '504.696',
#    'All': 100000,
#    'Maximum 1 light lepton': 99025,
#    'At least 2 leptons': 607,
#    'Exactly 2 leptons': 602,
#    'semileptonic selection': 529,
#    'At least 2 b_jets': 110,
#    'dLQ selection': 103,
#    'DeltaR > 0.3': 103},
#   'stop': {'XS': '241.17',
#    'All': 100000,
#    'Maximum 1 light lepton': 99689,
#    'At least 2 leptons': 196,
#    'Exactly 2 leptons': 194,
#    'semileptonic selection': 159,
#    'At least 2 b_jets': 9,
#    'dLQ selection': 9,
#    'DeltaR > 0.3': 9}}}
