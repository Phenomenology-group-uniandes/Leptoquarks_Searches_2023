# %% [markdown]
# $$\textrm{Joaquin Peñuela Parra}$$
# $$\textrm{University of Los Andes}$$
# $$\textrm{High Energy Physics Group: Phenomenology of Particles}$$
#
# $\textbf{Preliminaries}$
#
# The libraries used here are:

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["font.family"] = "serif"
format_figures = 'pdf'

# %%
Path_parton_analysis = os.path.dirname(os.path.realpath('Article_XS.ipynb'))
Path_Leptoquarks_searches = os.path.dirname(Path_parton_analysis)

# %%
Path_Leptoquarks_searches
# Out:
# '/disco4/personal_folders/Joaquin/2023/Semanas_13_14_15/Leptoquarks_Searches_2023'

# %%
Data = pd.read_csv(f'{Path_Leptoquarks_searches}/03_delphes_preselection/Cutflows/hadronic_dLQ.csv', index_col= 0)

# %%
Data
# Out:
#                                ttbar         stop       z_jets      w_jets  \
# XS                      5.046960e+02       241.17     43029.27    146548.3
# All                     2.430725e+07  11500000.00  18505572.00  20942823.0
# Maximum 1 light lepton  2.402979e+07  11463684.00  18232829.00  20942816.0
# At least 2 leptons      1.472470e+05     28042.00      2413.00      2083.0
# Exactly 2 leptons       1.458060e+05     27827.00      2407.00      2077.0
# hadronic selection      1.613900e+04      3472.00       760.00       272.0
# dLQ selection           3.047000e+03       287.00         4.00         1.0
# DeltaR > 0.3            3.047000e+03       287.00         4.00         1.0
#
#                                   ww            wz            zz  \
# XS                      6.550736e+01  2.469184e+01  9.562416e+00
# All                     1.250000e+07  9.850000e+06  1.000000e+07
# Maximum 1 light lepton  1.238944e+07  9.674837e+06  9.697543e+06
# At least 2 leptons      2.592700e+04  1.655200e+04  1.477700e+04
# Exactly 2 leptons       2.586200e+04  1.632700e+04  1.453000e+04
# hadronic selection      1.866000e+03  2.495000e+03  4.200000e+03
# dLQ selection           6.000000e+00  1.300000e+01  9.000000e+01
# DeltaR > 0.3            6.000000e+00  1.300000e+01  9.000000e+01
#
#                           LQ_LQ_1000     LQ_LQ_1250     LQ_LQ_1500  ...  \
# XS                           0.19567       0.033018       0.006541  ...
# All                     600000.00000  600000.000000  600000.000000  ...
# Maximum 1 light lepton  579636.00000  579652.000000  579698.000000  ...
# At least 2 leptons      100409.00000  100893.000000   99726.000000  ...
# Exactly 2 leptons        97457.00000   97798.000000   96517.000000  ...
# hadronic selection       41381.00000   41535.000000   40998.000000  ...
# dLQ selection            18557.00000   18708.000000   18637.000000  ...
# DeltaR > 0.3             18557.00000   18708.000000   18637.000000  ...
#
#                         Tau_LQ_wo_RHC_2000  Tau_LQ_wo_RHC_2250  \
# XS                                0.000301            0.000106
# All                          800000.000000       800000.000000
# Maximum 1 light lepton       769782.000000       770191.000000
# At least 2 leptons           144937.000000       143762.000000
# Exactly 2 leptons            141539.000000       140525.000000
# hadronic selection            59340.000000        59000.000000
# dLQ selection                  9676.000000         9900.000000
# DeltaR > 0.3                   9676.000000         9900.000000
#
#                         Tau_LQ_wo_RHC_2500  Tau_Tau_wo_RHC_1000  \
# XS                                0.000039              0.04198
# All                          800000.000000         150000.00000
# Maximum 1 light lepton       770967.000000         145007.00000
# At least 2 leptons           143550.000000          29007.00000
# Exactly 2 leptons            140219.000000          28829.00000
# hadronic selection            59252.000000          13030.00000
# dLQ selection                  9614.000000            367.00000
# DeltaR > 0.3                   9614.000000            367.00000
#
#                         Tau_Tau_wo_RHC_1250  Tau_Tau_wo_RHC_1500  \
# XS                                  0.01707             0.008189
# All                            150000.00000        150000.000000
# Maximum 1 light lepton         144839.00000        144734.000000
# At least 2 leptons              30329.00000         31320.000000
# Exactly 2 leptons               30142.00000         31129.000000
# hadronic selection              13744.00000         13870.000000
# dLQ selection                     381.00000           416.000000
# DeltaR > 0.3                      381.00000           416.000000
#
#                         Tau_Tau_wo_RHC_1750  Tau_Tau_wo_RHC_2000  \
# XS                                 0.004485             0.002816
# All                           150000.000000        150000.000000
# Maximum 1 light lepton        144322.000000        143981.000000
# At least 2 leptons             32466.000000         33372.000000
# Exactly 2 leptons              32275.000000         33138.000000
# hadronic selection             14367.000000         14766.000000
# dLQ selection                    425.000000           449.000000
# DeltaR > 0.3                     425.000000           449.000000
#
#                         Tau_Tau_wo_RHC_2250  Tau_Tau_wo_RHC_2500
# XS                                 0.002013             0.001612
# All                           150000.000000        150000.000000
# Maximum 1 light lepton        143697.000000        143549.000000
# At least 2 leptons             34838.000000         35421.000000
# Exactly 2 leptons              34597.000000         35183.000000
# hadronic selection             15245.000000         15306.000000
# dLQ selection                    488.000000           479.000000
# DeltaR > 0.3                     488.000000           479.000000
#
# [8 rows x 49 columns]

# %%
Signals = ['LQ_LQ', 'Tau_LQ', 'Tau_Tau']
Masses = ['1000', '1250', '1500', '1750', '2000', '2250', '2500']

Suffix_by_betard = {'wRHC': '', 'woRHC': '_wo_RHC'}
betard_label = {'wRHC': r'$\beta_{R} = -1$', 'woRHC': r'$\beta_{R} = 0$'}
linestyle_by_betard = {'wRHC': '-', 'woRHC': '--'}

colors = {'LQ_LQ_wRHC': 'orange', 
          'Tau_LQ_wRHC': 'blue', 
          'Tau_Tau_wRHC': 'green', 
          'LQ_LQ_woRHC': 'red', 
          'Tau_LQ_woRHC': 'dodgerblue', 
          'Tau_Tau_woRHC': 'limegreen'}

# %%
X = [float(M)/1000 for M in Masses]

fig = plt.figure(figsize = (5,6))

for betard in Suffix_by_betard.keys():
    for signal in Signals:
        etiqueta = signal.replace('Tau_LQ', r'sLQ : p p $\rightarrow \tau$ lq').replace('LQ_LQ', r'dLQ : p p $\rightarrow$ lq lq').replace('Tau_Tau', r'non-res : p p $\rightarrow \tau \tau$') + f', {betard_label[betard]}'
        # etiqueta = signal.replace('Tau_LQ', r'sLQ').replace('LQ_LQ', r'dLQ').replace('Tau_Tau', r'non-res') + f', {betard_label[betard]}'
        Y = [ Data[f'{signal}{Suffix_by_betard[betard]}_{M}']['XS'] for M in Masses]
        plt.plot(X, Y, linestyle = linestyle_by_betard[betard], label = etiqueta, color = colors[f'{signal}_{betard}']) 
        
plt.xlim(1,2.4)
plt.xlabel(r'$M_{U}$ [TeV]', loc= 'right', fontsize = 12)
plt.ylabel(r'$\sigma $ (pb)', loc = 'top', fontsize = 12)
plt.yscale('log')
plt.grid()
plt.legend()

plt.title(r'$\mathbf{\sqrt{s} = 13 TeV, g_{U} = 1.8}$', fontweight='bold', loc = 'right')
plt.savefig(f'prod_cross_section_13TeV.pdf', bbox_inches='tight')
